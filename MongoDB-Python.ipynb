# %% [markdown]
# # MongoDB Python Client
#
# References:
# https://pymongo.readthedocs.io/en/stable/tutorial.html
#
# Python library installation:
# `pip install pymongo`
#
# pymongo is an interface for connecting to a Mongo database server from Python. The steps are as follows:
#
# 1. Install and start MongoDB on your local machine.
# 2. Add MongoDB to your PATH environment variable
# 3. Make sure to run mongod with the data folder option
#     Windows: "mongod.exe" --dbpath "C:\data"
# 4. Download file
# https://raw.githubusercontent.com/mongodb/docs-assets/primer-dataset/primer-dataset.json
#
# 5. Import downloaded sample datasets into Mongo DB
#
# You can create the database using a client such as Compass, NoSQL Booster or the command line.
#
# <code>mongoimport --db food --collection restaurants --drop --file "primer-dataset.json"</code>

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.3.2-cp38-cp38-win_amd64.whl (381 kB)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.2.1 pymongo-4.3.2

# %%
#import libraries
import pymongo
from pymongo import MongoClient, GEO2D
from pprint import pprint
from bson.son import SON

# %% [markdown]
# ### Connect to MongoDB

# %%
#connect to local database server
client = MongoClient(host=['localhost:27017'])

#switch to Food DB
db = client.food

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'food')

# %% [markdown]
# ### Query MongoDB

# %%
#PyMongo collection object
db.restaurants
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'food'), 'restaurants')

# %%
#count total documents in collection
db.restaurants.count_documents({})
# Out:
# 25359

# %%
#print one document
firstDoc = db.restaurants.find_one()
pprint (firstDoc)
# Out:
# {'_id': ObjectId('6373ffc282aa0f9a79ed399f'),
#  'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': datetime.datetime(2014, 3, 3, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 9, 11, 0, 0),
#              'grade': 'A',
#              'score': 6},
#             {'date': datetime.datetime(2013, 1, 24, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2011, 11, 23, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2011, 3, 10, 0, 0),
#              'grade': 'B',
#              'score': 14}],
#  'name': 'Morris Park Bake Shop',
#  'restaurant_id': '30075445'}

# %%
#print a single attribute
pprint (firstDoc['cuisine'])
# Out:
# 'Bakery'

# %%
#find the first 10 documents in the db 
for doc in db.restaurants.find().limit(10):
    pprint(doc)
# Out:
# {'_id': ObjectId('6373ffc282aa0f9a79ed399f'),
#  'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': datetime.datetime(2014, 3, 3, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 9, 11, 0, 0),
#              'grade': 'A',
#              'score': 6},
#             {'date': datetime.datetime(2013, 1, 24, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2011, 11, 23, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2011, 3, 10, 0, 0),
#              'grade': 'B',
#              'score': 14}],
#  'name': 'Morris Park Bake Shop',
#  'restaurant_id': '30075445'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a0'),
#  'address': {'building': '469',
#              'coord': [-73.961704, 40.662942],
#              'street': 'Flatbush Avenue',
#              'zipcode': '11225'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Hamburgers',
#  'grades': [{'date': datetime.datetime(2014, 12, 30, 0, 0),
#              'grade': 'A',
#              'score': 8},
#             {'date': datetime.datetime(2014, 7, 1, 0, 0),
#              'grade': 'B',
#              'score': 23},
#             {'date': datetime.datetime(2013, 4, 30, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2012, 5, 8, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': "Wendy'S",
#  'restaurant_id': '30112340'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a1'),
#  'address': {'building': '351',
#              'coord': [-73.98513559999999, 40.7676919],
#              'street': 'West   57 Street',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Irish',
#  'grades': [{'date': datetime.datetime(2014, 9, 6, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 7, 22, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 7, 31, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2011, 12, 29, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': 'Dj Reynolds Pub And Restaurant',
#  'restaurant_id': '30191841'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a2'),
#  'address': {'building': '2780',
#              'coord': [-73.98241999999999, 40.579505],
#              'street': 'Stillwell Avenue',
#              'zipcode': '11224'},
#  'borough': 'Brooklyn',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 6, 10, 0, 0),
#              'grade': 'A',
#              'score': 5},
#             {'date': datetime.datetime(2013, 6, 5, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2012, 4, 13, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2011, 10, 12, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': 'Riviera Caterer',
#  'restaurant_id': '40356018'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a3'),
#  'address': {'building': '97-22',
#              'coord': [-73.8601152, 40.7311739],
#              'street': '63 Road',
#              'zipcode': '11374'},
#  'borough': 'Queens',
#  'cuisine': 'Jewish/Kosher',
#  'grades': [{'date': datetime.datetime(2014, 11, 24, 0, 0),
#              'grade': 'Z',
#              'score': 20},
#             {'date': datetime.datetime(2013, 1, 17, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2012, 8, 2, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2011, 12, 15, 0, 0),
#              'grade': 'B',
#              'score': 25}],
#  'name': 'Tov Kosher Kitchen',
#  'restaurant_id': '40356068'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a4'),
#  'address': {'building': '8825',
#              'coord': [-73.8803827, 40.7643124],
#              'street': 'Astoria Boulevard',
#              'zipcode': '11369'},
#  'borough': 'Queens',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 11, 15, 0, 0),
#              'grade': 'Z',
#              'score': 38},
#             {'date': datetime.datetime(2014, 5, 2, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2013, 3, 2, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2012, 2, 10, 0, 0),
#              'grade': 'A',
#              'score': 13}],
#  'name': 'Brunos On The Boulevard',
#  'restaurant_id': '40356151'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a5'),
#  'address': {'building': '2206',
#              'coord': [-74.1377286, 40.6119572],
#              'street': 'Victory Boulevard',
#              'zipcode': '10314'},
#  'borough': 'Staten Island',
#  'cuisine': 'Jewish/Kosher',
#  'grades': [{'date': datetime.datetime(2014, 10, 6, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2014, 5, 20, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 4, 4, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2012, 1, 24, 0, 0),
#              'grade': 'A',
#              'score': 9}],
#  'name': 'Kosher Island',
#  'restaurant_id': '40356442'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a6'),
#  'address': {'building': '7114',
#              'coord': [-73.9068506, 40.6199034],
#              'street': 'Avenue U',
#              'zipcode': '11234'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Delicatessen',
#  'grades': [{'date': datetime.datetime(2014, 5, 29, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2014, 1, 14, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2013, 8, 3, 0, 0),
#              'grade': 'A',
#              'score': 8},
#             {'date': datetime.datetime(2012, 7, 18, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2012, 3, 9, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2011, 10, 14, 0, 0),
#              'grade': 'A',
#              'score': 9}],
#  'name': "Wilken'S Fine Food",
#  'restaurant_id': '40356483'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a7'),
#  'address': {'building': '6409',
#              'coord': [-74.00528899999999, 40.628886],
#              'street': '11 Avenue',
#              'zipcode': '11219'},
#  'borough': 'Brooklyn',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 7, 18, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 7, 30, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 2, 13, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 8, 16, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2011, 8, 17, 0, 0),
#              'grade': 'A',
#              'score': 11}],
#  'name': 'Regina Caterers',
#  'restaurant_id': '40356649'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a8'),
#  'address': {'building': '1839',
#              'coord': [-73.9482609, 40.6408271],
#              'street': 'Nostrand Avenue',
#              'zipcode': '11226'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#  'grades': [{'date': datetime.datetime(2014, 7, 14, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 7, 10, 0, 0),
#              'grade': 'A',
#              'score': 8},
#             {'date': datetime.datetime(2012, 7, 11, 0, 0),
#              'grade': 'A',
#              'score': 5},
#             {'date': datetime.datetime(2012, 2, 23, 0, 0),
#              'grade': 'A',
#              'score': 8}],
#  'name': 'Taste The Tropics Ice Cream',
#  'restaurant_id': '40356731'}

# %%
#find all document where borough is Manhattan
query = {"borough": "Manhattan"}

print(db.restaurants.count_documents(query))

for doc in db.restaurants.find(query).limit(3):
    pprint(doc)
# Out:
# 10259
# {'_id': ObjectId('6373ffc282aa0f9a79ed39a1'),
#  'address': {'building': '351',
#              'coord': [-73.98513559999999, 40.7676919],
#              'street': 'West   57 Street',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Irish',
#  'grades': [{'date': datetime.datetime(2014, 9, 6, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 7, 22, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 7, 31, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2011, 12, 29, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': 'Dj Reynolds Pub And Restaurant',
#  'restaurant_id': '30191841'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39ac'),
#  'address': {'building': '1',
#              'coord': [-73.96926909999999, 40.7685235],
#              'street': 'East   66 Street',
#              'zipcode': '10065'},
#  'borough': 'Manhattan',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 5, 7, 0, 0),
#              'grade': 'A',
#              'score': 3},
#             {'date': datetime.datetime(2013, 5, 3, 0, 0),
#              'grade': 'A',
#              'score': 4},
#             {'date': datetime.datetime(2012, 4, 30, 0, 0),
#              'grade': 'A',
#              'score': 6},
#             {'date': datetime.datetime(2011, 12, 27, 0, 0),
#              'grade': 'A',
#              'score': 0}],
#  'name': '1 East 66Th Street Kitchen',
#  'restaurant_id': '40359480'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed39b1'),
#  'address': {'building': '522',
#              'coord': [-73.95171, 40.767461],
#              'street': 'East   74 Street',
#              'zipcode': '10021'},
#  'borough': 'Manhattan',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 9, 2, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 12, 19, 0, 0),
#              'grade': 'B',
#              'score': 16},
#             {'date': datetime.datetime(2013, 5, 28, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2012, 12, 7, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2012, 3, 29, 0, 0),
#              'grade': 'A',
#              'score': 11}],
#  'name': 'Glorious Food',
#  'restaurant_id': '40361521'}

# %% [markdown]
# #### Sort query results

# %%
#sort results in ascending order of borough and zipcode
for doc in db.restaurants.find().sort([
    ("borough", pymongo.ASCENDING),
    ("address.zipcode", pymongo.ASCENDING)]).limit(5):
    pprint(doc)
# Out:
# {'_id': ObjectId('6373ffc682aa0f9a79ed8cf3'),
#  'address': {'building': '650',
#              'coord': [-73.92537449999999, 40.8207116],
#              'street': 'Grand Concourse',
#              'zipcode': ''},
#  'borough': 'Bronx',
#  'cuisine': 'Sandwiches',
#  'grades': [{'date': datetime.datetime(2014, 9, 30, 0, 0),
#              'grade': 'A',
#              'score': 7}],
#  'name': 'Subway#50497 (Cardinal Hayes High School)',
#  'restaurant_id': '50006048'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed3d0c'),
#  'address': {'building': '101',
#              'coord': [-73.9243061, 40.8276297],
#              'street': 'East 161 Street',
#              'zipcode': '10451'},
#  'borough': 'Bronx',
#  'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'grades': [{'date': datetime.datetime(2014, 4, 10, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2013, 10, 1, 0, 0),
#              'grade': 'A',
#              'score': 6},
#             {'date': datetime.datetime(2013, 4, 11, 0, 0),
#              'grade': 'B',
#              'score': 25},
#             {'date': datetime.datetime(2012, 10, 25, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2012, 10, 10, 0, 0),
#              'grade': 'P',
#              'score': 12},
#             {'date': datetime.datetime(2012, 5, 25, 0, 0),
#              'grade': 'B',
#              'score': 14},
#             {'date': datetime.datetime(2011, 9, 14, 0, 0),
#              'grade': 'B',
#              'score': 26},
#             {'date': datetime.datetime(2011, 4, 25, 0, 0),
#              'grade': 'C',
#              'score': 76}],
#  'name': 'El Molino Rojo Restaurant',
#  'restaurant_id': '40393688'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed3a0c'),
#  'address': {'building': '72',
#              'coord': [-73.92506, 40.8275556],
#              'street': 'East  161 Street',
#              'zipcode': '10451'},
#  'borough': 'Bronx',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 4, 15, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2013, 11, 14, 0, 0),
#              'grade': 'A',
#              'score': 4},
#             {'date': datetime.datetime(2013, 7, 29, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2012, 12, 31, 0, 0),
#              'grade': 'B',
#              'score': 15},
#             {'date': datetime.datetime(2012, 5, 30, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2012, 1, 9, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2011, 8, 15, 0, 0),
#              'grade': 'C',
#              'score': 37}],
#  'name': 'Yankee Tavern',
#  'restaurant_id': '40365499'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed3f7c'),
#  'address': {'building': '79',
#              'coord': [-73.924914, 40.827846],
#              'street': 'East  161 Street',
#              'zipcode': '10451'},
#  'borough': 'Bronx',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 10, 10, 0, 0),
#              'grade': 'B',
#              'score': 18},
#             {'date': datetime.datetime(2014, 5, 9, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 11, 14, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 6, 6, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2012, 12, 28, 0, 0),
#              'grade': 'B',
#              'score': 26},
#             {'date': datetime.datetime(2012, 7, 16, 0, 0),
#              'grade': 'B',
#              'score': 18},
#             {'date': datetime.datetime(2011, 12, 23, 0, 0),
#              'grade': 'B',
#              'score': 27}],
#  'name': 'Crown Diner',
#  'restaurant_id': '40512746'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed3e29'),
#  'address': {'building': '599',
#              'coord': [-73.9270544, 40.8197704],
#              'street': 'Grand Concourse',
#              'zipcode': '10451'},
#  'borough': 'Bronx',
#  'cuisine': 'Hamburgers',
#  'grades': [{'date': datetime.datetime(2014, 2, 6, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2013, 9, 5, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 3, 26, 0, 0),
#              'grade': 'A',
#              'score': 5},
#             {'date': datetime.datetime(2012, 10, 2, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2012, 7, 19, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2012, 3, 6, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2011, 10, 11, 0, 0),
#              'grade': 'A',
#              'score': 7}],
#  'name': "Mcdonald'S",
#  'restaurant_id': '40399778'}

# %% [markdown]
# ### Create a Text Index and Search for text

# %%
#create a text index for searching
db.restaurants.create_index([('name', pymongo.TEXT)], name='search_index', default_language='english')
# Out:
# 'search_index'

# %%
#find all documents that have the word "Sport" on indexed fields
query = {"$text": {"$search": 'Sport'}}
      
print(db.restaurants.count_documents(query))

for doc in db.restaurants.find(query).limit(3):
    pprint(doc)
# Out:
# 83
# {'_id': ObjectId('6373ffc482aa0f9a79ed5ac5'),
#  'address': {'building': '920',
#              'coord': [-73.88843849999999, 40.8354789],
#              'street': 'East  173 Street',
#              'zipcode': '10460'},
#  'borough': 'Bronx',
#  'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'grades': [{'date': datetime.datetime(2014, 4, 24, 0, 0),
#              'grade': 'A',
#              'score': 3},
#             {'date': datetime.datetime(2013, 3, 19, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2012, 3, 7, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2011, 5, 6, 0, 0),
#              'grade': 'A',
#              'score': 2}],
#  'name': 'Sports Luncheonette',
#  'restaurant_id': '41334144'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed44ee'),
#  'address': {'building': '244',
#              'coord': [-73.95903109999999, 40.71347129999999],
#              'street': 'Grand Street',
#              'zipcode': '11211'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'grades': [{'date': datetime.datetime(2014, 10, 29, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2013, 10, 9, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2012, 10, 17, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': 'Caribbean Sports',
#  'restaurant_id': '40738973'}
# {'_id': ObjectId('6373ffc682aa0f9a79ed97cf'),
#  'address': {'building': '160',
#              'coord': [-73.9812224, 40.774571],
#              'street': 'Columbus Avenue',
#              'zipcode': '10023'},
#  'borough': 'Manhattan',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 11, 25, 0, 0),
#              'grade': 'Z',
#              'score': 20}],
#  'name': 'Equinox Sports Club',
#  'restaurant_id': '50015971'}

# %% [markdown]
# ### Insert data
#
# #### Insert a single document

# %%
#insert a new document
from datetime import datetime
result = db.restaurants.insert_one(
    {
        "address": {
            "street": "2 Avenue",
            "zipcode": "10075",
            "building": "1480",
            "coord": [-73.9557413, 40.7720266]
        },
        "borough": "Manhattan",
        "cuisine": "Italian",
        "grades": [
            {
                "date": datetime.strptime("2014-10-01", "%Y-%m-%d"),
                "grade": "A",
                "score": 11
            },
            {
                "date": datetime.strptime("2014-01-16", "%Y-%m-%d"),
                "grade": "B",
                "score": 17
            }
        ],
        "name": "Vella",
        "restaurant_id": "41704620"
    }
)

# %%
#print object type of the result
result

# %%
#check document that was inserted
result.inserted_id
# Out:
# ObjectId('6374011c65e856eaf723a42f')

# %% [markdown]
# #### Insert more than one documents

# %%
result = db.food.insert_many([{
        "address": {
            "street": "2 Avenue",
            "zipcode": "10075",
            "building": "1480",
            "coord": [-72.937413, 40.75466]
        },
        "borough": "Manhattan",
        "cuisine": "Indian",
        "grades": [
            {
                "date": datetime.strptime("2014-10-01", "%Y-%m-%d"),
                "grade": "A",
                "score": 11
            },
            {
                "date": datetime.strptime("2015-05-16", "%Y-%m-%d"),
                "grade": "B",
                "score": 17
            }
        ],
        "name": "India Garden",
        "restaurant_id": "4170462" + str(i)
    } for i in range(4)])

# %%
#documents that were inserted
result.inserted_ids
# Out:
# [ObjectId('6374013065e856eaf723a430'),
#  ObjectId('6374013065e856eaf723a431'),
#  ObjectId('6374013065e856eaf723a432'),
#  ObjectId('6374013065e856eaf723a433')]

# %% [markdown]
# ### Update documents
#
# update_one(),update_many()
#
# In MongoDB, a write operation is atomic on the level of a single document, even if the operation modifies multiple embedded documents within a single document.
#
# When a single write operation modifies multiple documents, the modification of each document is atomic, but the operation as a whole is not atomic and other operations may interleave.However, you can isolate a single write operation that affects multiple documents using the $isolated operator.

# %%
#update document 
result = db.restaurants.update_one(
    {"cuisine": "Indian"},
    {
        "$set": {
            "borough": "Manhattan",
            "name": "Mexican Garden"
        },
        "$currentDate": {"lastModified": True}
    }
)

# %%
#documents that were updated
print (result.matched_count)
print (result.modified_count)
cursor = db.restaurants.find({"name": "Mexican Garden"}).limit(10)
for document in cursor: 
    pprint(document)
# Out:
# 1
# 1
# {'_id': ObjectId('6373ffc282aa0f9a79ed3acd'),
#  'address': {'building': '320',
#              'coord': [-73.977597, 40.779593],
#              'street': 'Columbus Avenue',
#              'zipcode': '10023'},
#  'borough': 'Manhattan',
#  'cuisine': 'Indian',
#  'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2013, 7, 29, 0, 0),
#              'grade': 'A',
#              'score': 5},
#             {'date': datetime.datetime(2013, 2, 19, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 1, 12, 0, 0),
#              'grade': 'A',
#              'score': 2}],
#  'lastModified': datetime.datetime(2022, 11, 15, 21, 14, 52, 365000),
#  'name': 'Mexican Garden',
#  'restaurant_id': '40370243'}

# %% [markdown]
# ### Replace documents
#
# To replace the entire document rather than selected fields
#
# replace_one()

# %%
#update documents
#After the update, the document only contains the field or fields in the replacement document.
result = db.restaurants.replace_one(
    {"restaurant_id": "41704620"},
    {
        "name": "Mexican Garden",
        "cuisine": "Mexican",
        "address": {
            "coord": [-73.9557413, 40.7720266],
            "building": "1480",
            "street": "2 Avenue",
            "zipcode": "10075"
        }
    }
)

# %%
#documents that were updated
print (result.matched_count)
print (result.modified_count)

for doc in db.restaurants.find({"name": "Mexican Garden"}).limit(10):
    pprint(doc)
# Out:
# 1
# 1
# {'_id': ObjectId('6373ffc282aa0f9a79ed3acd'),
#  'address': {'building': '320',
#              'coord': [-73.977597, 40.779593],
#              'street': 'Columbus Avenue',
#              'zipcode': '10023'},
#  'borough': 'Manhattan',
#  'cuisine': 'Indian',
#  'grades': [{'date': datetime.datetime(2014, 10, 27, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2013, 7, 29, 0, 0),
#              'grade': 'A',
#              'score': 5},
#             {'date': datetime.datetime(2013, 2, 19, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 1, 12, 0, 0),
#              'grade': 'A',
#              'score': 2}],
#  'lastModified': datetime.datetime(2022, 11, 15, 21, 14, 52, 365000),
#  'name': 'Mexican Garden',
#  'restaurant_id': '40370243'}
# {'_id': ObjectId('6373ffc582aa0f9a79ed7e8b'),
#  'address': {'building': '1480',
#              'coord': [-73.9557413, 40.7720266],
#              'street': '2 Avenue',
#              'zipcode': '10075'},
#  'cuisine': 'Mexican',
#  'name': 'Mexican Garden'}

# %% [markdown]
# ### Data Aggregation, Grouping & Sorting
# Documents enter a multi-stage pipeline that transforms the documents into aggregated results

# %%
# Groups documents by city and get counts of each sorted in descending order
for doc in db.restaurants.aggregate(
        [ 
            { '$group': { '_id': "$borough", "count": { '$sum': 1 } } },
            { '$sort' : {'count' : -1} }
        ]
    ):
    pprint(doc)
# Out:
# {'_id': 'Manhattan', 'count': 10259}
# {'_id': 'Brooklyn', 'count': 6086}
# {'_id': 'Queens', 'count': 5656}
# {'_id': 'Bronx', 'count': 2338}
# {'_id': 'Staten Island', 'count': 969}
# {'_id': 'Missing', 'count': 51}
# {'_id': None, 'count': 1}

# %%
# find a list of restaurants located in the Bronx, grouped by cuisines
for doc in db.restaurants.aggregate( 
      [ 
          { '$match': { "borough": "Bronx" } },
          { '$group': { '_id': "$cuisine",  "count": { '$sum': 1 } } },
      ]  ):
    pprint(doc)
# Out:
# {'_id': 'Irish', 'count': 13}
# {'_id': 'Donuts', 'count': 68}
# {'_id': 'Bagels/Pretzels', 'count': 3}
# {'_id': 'Sandwiches', 'count': 49}
# {'_id': 'Hamburgers', 'count': 78}
# {'_id': 'Café/Coffee/Tea', 'count': 45}
# {'_id': 'Soul Food', 'count': 7}
# {'_id': 'Not Listed/Not Applicable', 'count': 2}
# {'_id': 'Other', 'count': 86}
# {'_id': 'Japanese', 'count': 17}
# {'_id': 'Bottled beverages, including water, sodas, juices, etc.', 'count': 3}
# {'_id': 'Soups & Sandwiches', 'count': 1}
# {'_id': 'African', 'count': 31}
# {'_id': 'Bakery', 'count': 71}
# {'_id': 'Caribbean', 'count': 110}
# {'_id': 'Hotdogs', 'count': 1}
# {'_id': 'Italian', 'count': 52}
# {'_id': 'Greek', 'count': 4}
# {'_id': 'Middle Eastern', 'count': 3}
# {'_id': 'Chicken', 'count': 108}
# {'_id': 'Pizza/Italian', 'count': 53}
# {'_id': 'Armenian', 'count': 2}
# {'_id': 'Chinese/Cuban', 'count': 4}
# {'_id': 'Bangladeshi', 'count': 5}
# {'_id': 'Spanish', 'count': 127}
# {'_id': 'Pizza', 'count': 197}
# {'_id': 'Mexican', 'count': 89}
# {'_id': 'Juice, Smoothies, Fruit Salads', 'count': 35}
# {'_id': 'Thai', 'count': 2}
# {'_id': 'Steak', 'count': 4}
# {'_id': 'Indian', 'count': 6}
# {'_id': 'Chinese/Japanese', 'count': 1}
# {'_id': 'Seafood', 'count': 26}
# {'_id': 'Delicatessen', 'count': 26}
# {'_id': 'American', 'count': 411}
# {'_id': 'Pancakes/Waffles', 'count': 4}
# {'_id': 'Peruvian', 'count': 2}
# {'_id': 'Jewish/Kosher', 'count': 8}
# {'_id': 'Chinese', 'count': 323}
# {'_id': 'Ice Cream, Gelato, Yogurt, Ices', 'count': 27}
# {'_id': 'Pakistani', 'count': 2}
# {'_id': 'Barbecue', 'count': 2}
# {'_id': 'French', 'count': 1}
# {'_id': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'count': 187}
# {'_id': 'Tex-Mex', 'count': 11}
# {'_id': 'Sandwiches/Salads/Mixed Buffet', 'count': 17}
# {'_id': 'Fruits/Vegetables', 'count': 1}
# {'_id': 'Asian', 'count': 4}
# {'_id': 'Mediterranean', 'count': 3}
# {'_id': 'Eastern European', 'count': 4}
# {'_id': 'Salads', 'count': 1}
# {'_id': 'Continental', 'count': 1}

# %%
# The following pipeline uses $match to query the restaurants collection for documents with borough 
# equal to "Queens" and cuisine equal to Brazilian. The _id field contains the distinct zipcode value.
for doc in db.restaurants.aggregate(
   [
     { '$match': { "borough": "Queens", "cuisine": "Brazilian" } },
     { '$group': { "_id": "$address.zipcode" , "count": { '$sum': 1 } } }
   ] ):
    pprint(doc)
# Out:
# {'_id': '11101', 'count': 2}
# {'_id': '11106', 'count': 3}
# {'_id': '11103', 'count': 1}
# {'_id': '11368', 'count': 1}
# {'_id': '11377', 'count': 1}

# %% [markdown]
# ### Geospatial Queries
#
# Reference: https://docs.mongodb.com/manual/geospatial-queries/

# %%
#find all restaurants with lat or long below value
for doc in db.restaurants.find({"address.coord" : {"$lt" : -95.754168}}).limit(3):
    pprint(doc)
# Out:
# {'_id': ObjectId('6373ffc282aa0f9a79ed3fe7'),
#  'address': {'building': '3707',
#              'coord': [-101.8945214, 33.5197474],
#              'street': '82 Street',
#              'zipcode': '11372'},
#  'borough': 'Queens',
#  'cuisine': 'American',
#  'grades': [{'date': datetime.datetime(2014, 6, 4, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 11, 7, 0, 0),
#              'grade': 'B',
#              'score': 19},
#             {'date': datetime.datetime(2013, 5, 17, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 8, 29, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 4, 3, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2011, 11, 16, 0, 0),
#              'grade': 'A',
#              'score': 7}],
#  'name': 'Burger King',
#  'restaurant_id': '40534067'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed4352'),
#  'address': {'building': '15259',
#              'coord': [-119.6368672, 36.2504996],
#              'street': '10 Avenue',
#              'zipcode': '11357'},
#  'borough': 'Queens',
#  'cuisine': 'Italian',
#  'grades': [{'date': datetime.datetime(2014, 9, 4, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2014, 3, 26, 0, 0),
#              'grade': 'A',
#              'score': 8},
#             {'date': datetime.datetime(2013, 3, 4, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2012, 9, 27, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2012, 4, 20, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2011, 11, 23, 0, 0),
#              'grade': 'C',
#              'score': 34}],
#  'name': "Cascarino'S",
#  'restaurant_id': '40668681'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed47f8'),
#  'address': {'building': '60',
#              'coord': [-111.9975205, 42.0970258],
#              'street': 'West Side Highway',
#              'zipcode': '10006'},
#  'borough': 'Manhattan',
#  'cuisine': 'Japanese',
#  'grades': [{'date': datetime.datetime(2014, 3, 20, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2013, 6, 28, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2012, 7, 5, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2011, 7, 27, 0, 0),
#              'grade': 'A',
#              'score': 2}],
#  'name': 'Sports Center At Chelsea Piers (Sushi Bar)',
#  'restaurant_id': '40882356'}

# %%
#create index for geospatial queries
db.restaurants.create_index([("address.coord", GEO2D)])
# Out:
# 'address.coord_2d'

# %%
#find all restaurants near a point 
#query = {"address.coord": SON([("$near", [-73.961704, 40.662942]), ("$maxDistance", 0.001)])}
query = {"address.coord": SON([("$near", [-73.961704, 40.662942]), ("$maxDistance", 0.01)])}
#query = {"address.coord": SON([("$near", [-73.961704, 40.662942]), ("$maxDistance", 0.1)])}

print(db.restaurants.find(query))#.count())#.count())

for doc in db.restaurants.find(query):
    pprint(doc['name'])
    pprint(doc['address'])
# Out:
# <pymongo.cursor.Cursor object at 0x0000016217DFEEE0>
# "Wendy'S"
# {'building': '469',
#  'coord': [-73.961704, 40.662942],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Popeyes Chicken & Biscuits'
# {'building': '40',
#  'coord': [-73.9612859, 40.6630911],
#  'street': 'Empire Boulevard',
#  'zipcode': '11225'}
# "Dunkin' Donuts"
# {'building': '40',
#  'coord': [-73.9612859, 40.6630911],
#  'street': 'Empire Boulevard',
#  'zipcode': '11225'}
# 'Checkers'
# {'building': '43',
#  'coord': [-73.9608544, 40.6633209],
#  'street': 'Empire Boulevard',
#  'zipcode': '11225'}
# "Franny'S"
# {'building': '346348',
#  'coord': [-73.9626285, 40.6634695],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11238'}
# 'Dj Oyster Inc'
# {'building': '504',
#  'coord': [-73.96186, 40.66173],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# "Gino'S Brick Oven Pizza & Trattoria"
# {'building': '548550',
#  'coord': [-73.96289569999999, 40.6638082],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# "Mcdonald'S Restaurant"
# {'building': '57',
#  'coord': [-73.960021, 40.66375],
#  'street': 'Empire Boulevard',
#  'zipcode': '11225'}
# 'China House Kitchen'
# {'building': '41',
#  'coord': [-73.961641, 40.661018],
#  'street': 'Lincoln Road',
#  'zipcode': '11225'}
# ''
# {'building': '41',
#  'coord': [-73.961641, 40.661018],
#  'street': 'Lincoln Rd',
#  'zipcode': '11225'}
# 'De Hot Pot'
# {'building': '1127',
#  'coord': [-73.9605021, 40.6614159],
#  'street': 'Washington  Avenue',
#  'zipcode': '11225'}
# 'Lincoln Park Tavern'
# {'building': '534',
#  'coord': [-73.9614187, 40.6609931],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Tip Of The Tongue Cafe'
# {'building': '43',
#  'coord': [-73.96145039999999, 40.6609012],
#  'street': 'Lincoln Road',
#  'zipcode': '11225'}
# 'New Peking'
# {'building': '1137',
#  'coord': [-73.9606684, 40.6611406],
#  'street': 'Washington Ave',
#  'zipcode': '11225'}
# 'New Peking Restaurant'
# {'building': '1137',
#  'coord': [-73.9606684, 40.6611406],
#  'street': 'Washington Avenue',
#  'zipcode': '11225'}
# 'Tugboat Tea Company'
# {'building': '546',
#  'coord': [-73.9607163, 40.66058],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Jus Fishy'
# {'building': '555',
#  'coord': [-73.9604956, 40.6604043],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Brooklyn Greenery'
# {'building': '560',
#  'coord': [-73.9607939, 40.6601991],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Subway'
# {'building': '2121',
#  'coord': [-73.9608842, 40.6601355],
#  'street': 'Beekman Place',
#  'zipcode': '11225'}
# "Erv'S"
# {'building': '2122',
#  'coord': [-73.9609833, 40.6599086],
#  'street': 'Beekman Pl',
#  'zipcode': '11225'}
# 'Buzz'
# {'building': '103',
#  'coord': [-73.958612, 40.663832],
#  'street': 'Empire Boulevard',
#  'zipcode': '11225'}
# 'Bay Leaf Indian Food'
# {'building': '561',
#  'coord': [-73.9603249, 40.66002719999999],
#  'street': 'Flatbush Ave',
#  'zipcode': '11225'}
# 'Golden Krust'
# {'building': '568',
#  'coord': [-73.9609248, 40.6597909],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Midwood Flats'
# {'building': '577',
#  'coord': [-73.9605613, 40.6595299],
#  'street': 'Flatbush Ave',
#  'zipcode': '11225'}
# 'New Golden  Restaurant'
# {'building': '579',
#  'coord': [-73.9603839, 40.659401],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# "Trinidad Ali'S Roti Shop #2"
# {'building': '589',
#  'coord': [-73.960243, 40.65913],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'King Of Tandoor'
# {'building': '600',
#  'coord': [-73.960807, 40.6588769],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Pizza Hut #29773'
# {'building': '140',
#  'coord': [-73.9573968, 40.6634894],
#  'street': 'Empire Boulevard',
#  'zipcode': '11225'}
# "Mike & Tony'S Pizza"
# {'building': '599',
#  'coord': [-73.9603391, 40.6586808],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Brooklyn Botanic Catering Hall'
# {'building': '1000',
#  'coord': [-73.9619036, 40.6675708],
#  'street': 'Washington Avenue',
#  'zipcode': '11225'}
# 'The Atrium'
# {'building': '1000',
#  'coord': [-73.9619036, 40.6675708],
#  'street': 'Washington Avenue',
#  'zipcode': '11225'}
# 'Yellow Magnolia'
# {'building': '1000',
#  'coord': [-73.9619036, 40.6675708],
#  'street': 'Washington Avenue',
#  'zipcode': '11225'}
# 'Burger King'
# {'building': '1727',
#  'coord': [-73.9570007, 40.664132],
#  'street': 'Bedford Avenue',
#  'zipcode': '11225'}
# 'Blue Nile Restaurant'
# {'building': '621',
#  'coord': [-73.9601795, 40.6582206],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Scoops'
# {'building': '624',
#  'coord': [-73.9604454, 40.6581204],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# "Delroy'S"
# {'building': '65A',
#  'coord': [-73.9600574, 40.6581279],
#  'street': 'Fenimore Street',
#  'zipcode': '11225'}
# 'Sushi Tatsu Japanese Restaurant Iii'
# {'building': '644',
#  'coord': [-73.96061399999999, 40.657557],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Hai Sun Restaurant'
# {'building': '651',
#  'coord': [-73.96014799999999, 40.657577],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Mountain'
# {'building': '903',
#  'coord': [-73.958871, 40.6677696],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# "Sultan'S Pizza"
# {'building': '666',
#  'coord': [-73.96037919999999, 40.6570786],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Balboa Restaurant.'
# {'building': '1655',
#  'coord': [-73.9565078, 40.66607920000001],
#  'street': 'Bedford Avenue',
#  'zipcode': '11225'}
# "Errol'S Bakery"
# {'building': '661',
#  'coord': [-73.959898, 40.65711],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Bluestone Lakeside Cafe'
# {'building': '171',
#  'coord': [-73.9648424, 40.657621],
#  'street': 'East Drive',
#  'zipcode': '11226'}
# 'Blessings Herbs & Coffee'
# {'building': '663',
#  'coord': [-73.959884, 40.657034],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Skylight Cafe (Medgar Evers College)'
# {'building': '1638',
#  'coord': [-73.95667949999999, 40.6667997],
#  'street': 'Bedford Avenue',
#  'zipcode': '11225'}
# 'D Avenue'
# {'building': '673',
#  'coord': [-73.959819, 40.656823],
#  'street': 'Flatbush Ave',
#  'zipcode': '11225'}
# 'Careta Bar & Restaurant'
# {'building': '679',
#  'coord': [-73.959794, 40.656717],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Charles Sally & Charles'
# {'building': '990',
#  'coord': [-73.96340889999999, 40.66931719999999],
#  'street': 'Washington Avenue',
#  'zipcode': '11225'}
# "Billy'S Pizza Pasta"
# {'building': '1626',
#  'coord': [-73.956571, 40.66713910000001],
#  'street': 'Bedford Avenue',
#  'zipcode': '11225'}
# 'Subway'
# {'building': '1622',
#  'coord': [-73.9565102, 40.6672384],
#  'street': 'Bedford Avenue',
#  'zipcode': '11225'}
# 'Shanghai Restaurant'
# {'building': '854',
#  'coord': [-73.958839, 40.6690627],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# 'Italian Passion Cafe & Pizza Restaurant'
# {'building': '842',
#  'coord': [-73.9587627, 40.6692834],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# 'Family Pizza'
# {'building': '720',
#  'coord': [-73.9600746, 40.6558265],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'The Pulp & The Bean'
# {'building': '832',
#  'coord': [-73.9585349, 40.6695214],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# 'Popeyes Chicken & Biscuits'
# {'building': '722',
#  'coord': [-73.96006229999999, 40.6557787],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# "Jj'S Jamaican Restaurant"
# {'building': '711',
#  'coord': [-73.95958, 40.655838],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11225'}
# 'Fever Grass'
# {'building': '843',
#  'coord': [-73.95806, 40.669466],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# 'New Peking Restaurant'
# {'building': '837A',
#  'coord': [-73.9582298, 40.6696297],
#  'street': 'Franklin Ave',
#  'zipcode': '11225'}
# 'Ital Kitchen'
# {'building': '1032',
#  'coord': [-73.9578658, 40.6695176],
#  'street': 'Union Street',
#  'zipcode': '11225'}
# "Fisherman'S Cove"
# {'building': '218',
#  'coord': [-73.9605686, 40.6553803],
#  'street': 'Parkside Avenue',
#  'zipcode': '11226'}
# 'Butter & Scotch'
# {'building': '818',
#  'coord': [-73.958366, 40.6699907],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# 'Great Wall Chinese Restaurant'
# {'building': '719',
#  'coord': [-73.959496, 40.655455],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# "Dunkin' Donuts"
# {'building': '721',
#  'coord': [-73.95963669999999, 40.65540379999999],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# "Sal'S Restaurant"
# {'building': '810',
#  'coord': [-73.95839529999999, 40.6702664],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# '188 Fast Food Inc'
# {'building': '188',
#  'coord': [-73.96119999999999, 40.654848],
#  'street': 'Parkside Ave',
#  'zipcode': '11226'}
# 'Gyro Cafe'
# {'building': '188',
#  'coord': [-73.96119999999999, 40.654848],
#  'street': 'Parkside Ave',
#  'zipcode': '11226'}
# 'Parkside Coffee Shop'
# {'building': '188',
#  'coord': [-73.96119999999999, 40.654848],
#  'street': 'Parkside Avenue',
#  'zipcode': '11226'}
# 'Golden Krust Caribbean Bakery & Grill'
# {'building': '823',
#  'coord': [-73.9579583, 40.670145],
#  'street': 'Franklin Avenue',
#  'zipcode': '11225'}
# "Mcdonald'S Restaurant #3391"
# {'building': '180',
#  'coord': [-73.9615283, 40.6547688],
#  'street': 'Parkside Avenue',
#  'zipcode': '11226'}
# 'Peppas Jerk Chicken Restaurant'
# {'building': '738',
#  'coord': [-73.9598948, 40.6549662],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# 'Subway'
# {'building': '739',
#  'coord': [-73.9594779, 40.6549693],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# 'Li Wing Hing Restaurant Inc'
# {'building': '312',
#  'coord': [-73.953897, 40.66583199999999],
#  'street': 'Rogers Avenue',
#  'zipcode': '11225'}
# 'Saul @ Brooklyn Museum'
# {'building': '200',
#  'coord': [-73.96347659999999, 40.671151],
#  'street': 'Eastern Parkway',
#  'zipcode': '11238'}
# 'Museum Cafe'
# {'building': '200',
#  'coord': [-73.96347659999999, 40.671151],
#  'street': 'Eastern Parkway',
#  'zipcode': '11238'}
# 'J & R West Indian Restaurant'
# {'building': '294',
#  'coord': [-73.953863, 40.66622599999999],
#  'street': 'Rogers Avenue',
#  'zipcode': '11225'}
# 'Starbucks Coffee #23266'
# {'building': '341',
#  'coord': [-73.9574705, 40.6706084],
#  'street': 'Eastern Parkway',
#  'zipcode': '11216'}
# 'Mango Seed Restaurant'
# {'building': '757',
#  'coord': [-73.9593385, 40.6544119],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# 'Astramed Physician, P.C'
# {'building': '759',
#  'coord': [-73.95943539999999, 40.654369],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# 'Tacos El Dorado'
# {'building': '763A',
#  'coord': [-73.9594161, 40.6542732],
#  'street': 'Flatbush Ave',
#  'zipcode': '11226'}
# 'The Local Ice Cream'
# {'building': '843',
#  'coord': [-73.9611369, 40.6719058],
#  'street': 'Classon Avenue',
#  'zipcode': '11238'}
# 'Gratitude Cafe'
# {'building': '499',
#  'coord': [-73.953187, 40.660055],
#  'street': 'Rogers Avenue',
#  'zipcode': '11225'}
# 'Pacificos Fine Foods'
# {'building': '798A',
#  'coord': [-73.957927, 40.6712038],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Kam Po'
# {'building': '2018',
#  'coord': [-73.9565686, 40.6554102],
#  'street': 'Bedford Avenue',
#  'zipcode': '11226'}
# 'El Barrio Burritos'
# {'building': '796A',
#  'coord': [-73.9579043, 40.671267],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Bamboo Express Restaurant & Bakery'
# {'building': '772',
#  'coord': [-73.9598132, 40.6539719],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# "Mike'S Pizza Of Brooklyn"
# {'building': '2026',
#  'coord': [-73.95656009999999, 40.6553397],
#  'street': 'Bedford Avenue',
#  'zipcode': '11226'}
# 'Zen Vegetarian House'
# {'building': '773',
#  'coord': [-73.9593045, 40.6539596],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# 'The Pulp And The Bean'
# {'building': '809',
#  'coord': [-73.9577042, 40.671359],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Gandhi Indian Restaurant'
# {'building': '2032',
#  'coord': [-73.956481, 40.6552063],
#  'street': 'Bedford Avenue',
#  'zipcode': '11226'}
# 'Dragon House'
# {'building': '803',
#  'coord': [-73.9624826, 40.6723542],
#  'street': 'Washington Avenue',
#  'zipcode': '11238'}
# 'The Islands'
# {'building': '803',
#  'coord': [-73.9624826, 40.6723542],
#  'street': 'Washington Avenue',
#  'zipcode': '11238'}
# 'Morris Sandwich Shop'
# {'building': '788',
#  'coord': [-73.9579042, 40.67171099999999],
#  'street': 'Franklin Ave',
#  'zipcode': '11238'}
# "Glady'S"
# {'building': '788',
#  'coord': [-73.9579042, 40.67171099999999],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Lincoln Station'
# {'building': '409',
#  'coord': [-73.9624807, 40.6726965],
#  'street': 'Lincoln Place',
#  'zipcode': '11238'}
# '95 South'
# {'building': '778',
#  'coord': [-73.9578089, 40.6719225],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Melany Restaurant'
# {'building': '785',
#  'coord': [-73.9591525, 40.653453],
#  'street': 'Flatbush Avenue',
#  'zipcode': '11226'}
# 'Golden Chopsticks Chinese Restaurant'
# {'building': '789',
#  'coord': [-73.9573187, 40.6718433],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Docklands'
# {'building': '789',
#  'coord': [-73.9573187, 40.6718433],
#  'street': 'Franklin Avenue',
#  'zipcode': '11238'}
# 'Tooker Alley'
# {'building': '793',
#  'coord': [-73.9625476, 40.6728692],
#  'street': 'Washington Avenue',
#  'zipcode': '11238'}

# %% [markdown]
#  1. List 10 of the Asian restaurants in Bronx
#  2. Count total number of the French restaurants in Queens
#  3. Count total number of the cafes in all the boroughs
#  4. Find the restaurants close to the World Trade Center

# %%
# 1
for doc in db.restaurants.find({"cuisine": "Asian"}).limit(10):
    pprint(doc)
# Out:
# {'_id': ObjectId('6373ffc282aa0f9a79ed3c11'),
#  'address': {'building': '51',
#              'coord': [-73.9787406, 40.7611474],
#              'street': 'West 52 Street',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 8, 12, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2013, 8, 27, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2013, 4, 3, 0, 0),
#              'grade': 'B',
#              'score': 18},
#             {'date': datetime.datetime(2012, 9, 20, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2011, 8, 17, 0, 0),
#              'grade': 'A',
#              'score': 2}],
#  'name': 'China Grill',
#  'restaurant_id': '40386481'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed3d12'),
#  'address': {'building': '430',
#              'coord': [-73.992465, 40.729258],
#              'street': 'Lafayette Street',
#              'zipcode': '10003'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 11, 18, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2013, 9, 19, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 2, 13, 0, 0),
#              'grade': 'A',
#              'score': 5},
#             {'date': datetime.datetime(2012, 7, 3, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2012, 1, 25, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': 'Indo Chine',
#  'restaurant_id': '40393772'}
# {'_id': ObjectId('6373ffc282aa0f9a79ed3dc1'),
#  'address': {'building': '149',
#              'coord': [-73.968322, 40.760905],
#              'street': 'East   57 Street',
#              'zipcode': '10022'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 8, 26, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 5, 28, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2012, 5, 16, 0, 0),
#              'grade': 'A',
#              'score': 8},
#             {'date': datetime.datetime(2012, 1, 4, 0, 0),
#              'grade': 'B',
#              'score': 24}],
#  'name': 'Le Colonial',
#  'restaurant_id': '40397478'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed41d3'),
#  'address': {'building': '320',
#              'coord': [-73.980368, 40.780879],
#              'street': 'Amsterdam Avenue',
#              'zipcode': '10023'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 11, 13, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2013, 9, 11, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2013, 2, 12, 0, 0),
#              'grade': 'C',
#              'score': 30},
#             {'date': datetime.datetime(2012, 5, 23, 0, 0),
#              'grade': 'B',
#              'score': 18},
#             {'date': datetime.datetime(2011, 12, 17, 0, 0),
#              'grade': 'A',
#              'score': 13}],
#  'name': 'Citrus Bar & Grill',
#  'restaurant_id': '40593202'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed430c'),
#  'address': {'building': '7173',
#              'coord': [-74.0099177, 40.7146687],
#              'street': 'West Broadway',
#              'zipcode': '10007'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 10, 9, 0, 0),
#              'grade': 'A',
#              'score': 10},
#             {'date': datetime.datetime(2013, 8, 14, 0, 0),
#              'grade': 'A',
#              'score': 4},
#             {'date': datetime.datetime(2013, 3, 13, 0, 0),
#              'grade': 'B',
#              'score': 26},
#             {'date': datetime.datetime(2012, 9, 25, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2012, 4, 9, 0, 0),
#              'grade': 'B',
#              'score': 18},
#             {'date': datetime.datetime(2011, 11, 15, 0, 0),
#              'grade': 'A',
#              'score': 11}],
#  'name': 'Mangez Avec Moi',
#  'restaurant_id': '40658444'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed435e'),
#  'address': {'building': '8616',
#              'coord': [-74.028843, 40.622419],
#              'street': '4 Avenue',
#              'zipcode': '11209'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 8, 19, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2014, 1, 27, 0, 0),
#              'grade': 'B',
#              'score': 16},
#             {'date': datetime.datetime(2013, 5, 30, 0, 0),
#              'grade': 'B',
#              'score': 18},
#             {'date': datetime.datetime(2012, 10, 16, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2012, 3, 20, 0, 0),
#              'grade': 'B',
#              'score': 26}],
#  'name': 'Pho Hoai Bay Ridge',
#  'restaurant_id': '40671249'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed44a9'),
#  'address': {'building': '1626',
#              'coord': [-73.984011, 40.7610605],
#              'street': 'Broadway',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 11, 17, 0, 0),
#              'grade': 'A',
#              'score': 9},
#             {'date': datetime.datetime(2013, 10, 24, 0, 0),
#              'grade': 'A',
#              'score': 7},
#             {'date': datetime.datetime(2012, 9, 11, 0, 0),
#              'grade': 'A',
#              'score': 12}],
#  'name': "Ruby Foo'S Times Square",
#  'restaurant_id': '40730396'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed459e'),
#  'address': {'building': '1720',
#              'coord': [-73.9498632, 40.7799512],
#              'street': '2 Avenue',
#              'zipcode': '10128'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 11, 13, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2014, 5, 28, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2013, 9, 9, 0, 0),
#              'grade': 'B',
#              'score': 16},
#             {'date': datetime.datetime(2013, 3, 20, 0, 0),
#              'grade': 'C',
#              'score': 33},
#             {'date': datetime.datetime(2012, 8, 20, 0, 0),
#              'grade': 'B',
#              'score': 17}],
#  'name': "Chef Ho'S",
#  'restaurant_id': '40763888'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed45f8'),
#  'address': {'building': '42',
#              'coord': [-73.971395, 40.7626186],
#              'street': 'East   58 Street',
#              'zipcode': '10022'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 10, 16, 0, 0),
#              'grade': 'A',
#              'score': 13},
#             {'date': datetime.datetime(2013, 10, 1, 0, 0),
#              'grade': 'A',
#              'score': 2},
#             {'date': datetime.datetime(2012, 10, 3, 0, 0),
#              'grade': 'A',
#              'score': 11},
#             {'date': datetime.datetime(2011, 10, 26, 0, 0),
#              'grade': 'A',
#              'score': 10}],
#  'name': 'Tao Restaurant',
#  'restaurant_id': '40795021'}
# {'_id': ObjectId('6373ffc382aa0f9a79ed46a5'),
#  'address': {'building': '14',
#              'coord': [-73.9985052, 40.7141563],
#              'street': 'Mott Street',
#              'zipcode': '10013'},
#  'borough': 'Manhattan',
#  'cuisine': 'Asian',
#  'grades': [{'date': datetime.datetime(2014, 4, 8, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2013, 4, 5, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2012, 2, 7, 0, 0),
#              'grade': 'A',
#              'score': 12},
#             {'date': datetime.datetime(2011, 7, 7, 0, 0),
#              'grade': 'A',
#              'score': 9}],
#  'name': 'Ajisen Ramen',
#  'restaurant_id': '40827287'}

# %%
# 2
query = {"borough": "Queens", "cuisine": "French"}
print(db.restaurants.count_documents(query))
# Out:
# 21

# %%
# 3
for doc in db.restaurants.aggregate(
   [
     #{ '$match': { "borough": "Queens", "cuisine": "French" } },
     { '$group': { "_id": "$borough" , "count": { '$sum': 1 } } }
   ] ):
    pprint(doc)
# Out:
# {'_id': 'Missing', 'count': 51}
# {'_id': None, 'count': 1}
# {'_id': 'Brooklyn', 'count': 6086}
# {'_id': 'Manhattan', 'count': 10259}
# {'_id': 'Bronx', 'count': 2338}
# {'_id': 'Queens', 'count': 5656}
# {'_id': 'Staten Island', 'count': 969}

# %%
# 4
# World Trade Center - 40.7118° N, 74.0131° W
query = {"address.coord": SON([("$near", [-74.0131, 40.7118]), ("$maxDistance", 0.01)])}

for doc in db.restaurants.find(query):
    pprint(doc['name'])
    pprint(doc['address'])
# Out:
# 'Conde Nast'
# {'building': '1',
#  'coord': [-74.0131689, 40.7130082],
#  'street': 'World Trade Center',
#  'zipcode': '10048'}
# 'Ho Yip Restaurant'
# {'building': '110112',
#  'coord': [-74.012778, 40.710278],
#  'street': 'Liberty Street',
#  'zipcode': '10006'}
# "George'S"
# {'building': '8789',
#  'coord': [-74.011933, 40.710409],
#  'street': 'Greenwich Street',
#  'zipcode': '10006'}
# 'N.Y. Academy Of Science'
# {'building': '250',
#  'coord': [-74.0121273, 40.713351],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# "Moody'S Cafeteria"
# {'building': '250',
#  'coord': [-74.0121273, 40.713351],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# 'Wilmer Hale'
# {'building': '7',
#  'coord': [-74.0120762, 40.7133882],
#  'street': 'World Trade Center',
#  'zipcode': '10007'}
# 'Pronto Pizza'
# {'building': '114',
#  'coord': [-74.01215979999999, 40.7097678],
#  'street': 'Liberty Street',
#  'zipcode': '10006'}
# "Morton'S The Steakhouse"
# {'building': '136',
#  'coord': [-74.0139508, 40.7097089],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'View Of The World Terrace Club'
# {'building': '140',
#  'coord': [-74.01406469999999, 40.7097179],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# "O'Hara'S"
# {'building': '120',
#  'coord': [-74.01268830000001, 40.7095273],
#  'street': 'Cedar Street',
#  'zipcode': '10006'}
# 'Ruchi Indian Cuisine'
# {'building': '120',
#  'coord': [-74.01268830000001, 40.7095273],
#  'street': 'Cedar Street',
#  'zipcode': '10006'}
# 'Essex World Cafe'
# {'building': '112',
#  'coord': [-74.01212939999999, 40.7095448],
#  'street': 'Liberty Street',
#  'zipcode': '10006'}
# 'Burger King'
# {'building': '106',
#  'coord': [-74.0119117, 40.7096373],
#  'street': 'Liberty Street',
#  'zipcode': '10006'}
# 'Starbucks/New York Marriott Financial Center'
# {'building': '85',
#  'coord': [-74.01448359999999, 40.7096119],
#  'street': 'West Street',
#  'zipcode': '10006'}
# "Bill'S Bar And Burger Downtown"
# {'building': '85',
#  'coord': [-74.01448359999999, 40.7096119],
#  'street': 'West Street',
#  'zipcode': '10006'}
# 'Banquet Kitchen (Marriott)'
# {'building': '85',
#  'coord': [-74.01448359999999, 40.7096119],
#  'street': 'West Street',
#  'zipcode': '10006'}
# 'Dig Inn Seasonal Market'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# "Mighty Quinn'S Bbq"
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# "Chop'T Wfc"
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Little Muenster'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Northern Tiger'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty St',
#  'zipcode': '10281'}
# 'Dos Toros'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Tartinery'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Blue Ribbon Sushi Bar'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty St - Space #244',
#  'zipcode': '10281'}
# 'Skinnypizza'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Black Seed Bagels'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# "Olive'S"
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty St',
#  'zipcode': '10281'}
# 'Umami Burger'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Num Pang Sandwich Shop'
# {'building': '225',
#  'coord': [-74.0156618, 40.71137470000001],
#  'street': 'Liberty Street',
#  'zipcode': '10280'}
# 'Charlys'
# {'building': '110',
#  'coord': [-74.0118048, 40.70953799999999],
#  'street': 'Trinity Place',
#  'zipcode': '10006'}
# 'Cafe 101 16Th Floor Cafeteria'
# {'building': '101',
#  'coord': [-74.01231039999999, 40.7143002],
#  'street': 'Barclay Street',
#  'zipcode': '10007'}
# 'Cafe 101'
# {'building': '101',
#  'coord': [-74.01231039999999, 40.7143002],
#  'street': 'Barclay Street',
#  'zipcode': '10007'}
# 'The Living Room'
# {'building': '123',
#  'coord': [-74.0137534, 40.7092191],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Go Burger'
# {'building': '123',
#  'coord': [-74.0137534, 40.7092191],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Blt Bar & Grill'
# {'building': '123',
#  'coord': [-74.0137534, 40.7092191],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Au Bon Pain'
# {'building': '200',
#  'coord': [-74.015526, 40.710651],
#  'street': 'Liberty Street',
#  'zipcode': '10281'}
# 'Starbucks Coffee'
# {'building': '200',
#  'coord': [-74.015526, 40.710651],
#  'street': 'Liberty Street',
#  'zipcode': '10281'}
# 'Willis North America'
# {'building': '200',
#  'coord': [-74.015526, 40.710651],
#  'street': 'Liberty Street',
#  'zipcode': '10281'}
# 'Sprinkles Cupcakes'
# {'building': '200',
#  'coord': [-74.0154858, 40.7130392],
#  'street': 'Vesey Street',
#  'zipcode': '10281'}
# 'Devon And Blakely'
# {'building': '1',
#  'coord': [-74.0154858, 40.7130392],
#  'street': 'World Financial Center',
#  'zipcode': '10280'}
# 'Cadwalader, Wickersham & Taft'
# {'building': '1',
#  'coord': [-74.0154858, 40.7130392],
#  'street': 'World Financial Center',
#  'zipcode': '10280'}
# 'American Express'
# {'building': '200',
#  'coord': [-74.0154858, 40.7130392],
#  'street': 'Vesey Street',
#  'zipcode': '10281'}
# 'Eurest Dining Service (American Express)'
# {'building': '200',
#  'coord': [-74.0154858, 40.7130392],
#  'street': 'Vesey Street',
#  'zipcode': '10281'}
# 'Canteen Cafe'
# {'building': '125',
#  'coord': [-74.0130191, 40.714526],
#  'street': 'Barclay Street',
#  'zipcode': '10007'}
# 'Barclay Street Cafe'
# {'building': '245',
#  'coord': [-74.0113113, 40.7139004],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# 'Blue Planet Grill'
# {'building': '120',
#  'coord': [-74.01331669999999, 40.7090409],
#  'street': 'Greenwich Street',
#  'zipcode': '10006'}
# 'Cafe Express'
# {'building': '397',
#  'coord': [-74.01589299999999, 40.7115385],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# 'Millenium Hilton'
# {'building': '55',
#  'coord': [-74.0103057, 40.7111618],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Wafflaki Belgian Waffle Bar'
# {'building': '97',
#  'coord': [-74.0118513, 40.7090938],
#  'street': 'Trinity Place',
#  'zipcode': '10006'}
# 'Tet Test'
# {'building': '22',
#  'coord': [-74.0104657, 40.7103768],
#  'street': 'Cortlandt Street',
#  'zipcode': '10007'}
# 'The Coffee Bean & Tea Leaf'
# {'building': '22',
#  'coord': [-74.0104657, 40.7103768],
#  'street': 'Cortlandt Street',
#  'zipcode': '10007'}
# 'Cleary Gottlieb'
# {'building': '1',
#  'coord': [-74.0109533, 40.7096139],
#  'street': 'Liberty Plaza',
#  'zipcode': '10006'}
# 'Big Als Chicago Pizza'
# {'building': '9',
#  'coord': [-74.01185749999999, 40.7089582],
#  'street': 'Thames Street',
#  'zipcode': '10006'}
# 'Starbucks Coffee'
# {'building': '165',
#  'coord': [-74.0109418, 40.7095523],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Pret A Manger'
# {'building': '100',
#  'coord': [-74.0102115, 40.713174],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Aroma Espresso Bar'
# {'building': '100',
#  'coord': [-74.0102115, 40.713174],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Eliezer Kitchen'
# {'building': '100',
#  'coord': [-74.0102115, 40.713174],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Goldman Sachs'
# {'building': '200',
#  'coord': [-74.0142077, 40.7148476],
#  'street': 'West Street',
#  'zipcode': '10282'}
# 'Fp Bakery'
# {'building': '200',
#  'coord': [-74.0142077, 40.7148476],
#  'street': 'West Street',
#  'zipcode': '10282'}
# 'Goldman Sachs'
# {'building': '200',
#  'coord': [-74.0142077, 40.7148476],
#  'street': 'West Street',
#  'zipcode': '10282'}
# 'Majestic Pizza'
# {'building': '8',
#  'coord': [-74.010318, 40.7100628],
#  'street': 'Cortlandt Street',
#  'zipcode': '10007'}
# 'Merchants River House'
# {'building': '375',
#  'coord': [-74.01636049999999, 40.7113097],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# 'Subway'
# {'building': '106',
#  'coord': [-74.0135268, 40.7085198],
#  'street': 'Greenwich Street',
#  'zipcode': '10006'}
# 'Arome Cafe Ii'
# {'building': '7',
#  'coord': [-74.01006029999999, 40.7104936],
#  'street': 'Dey Street',
#  'zipcode': '10007'}
# 'Boonrasa Thai Food'
# {'building': '109',
#  'coord': [-74.013987, 40.708573],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Panini & Co'
# {'building': '115',
#  'coord': [-74.01143259999999, 40.708882],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Trinity Place Bar & Restaurant'
# {'building': '115',
#  'coord': [-74.01143259999999, 40.708882],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Starbucks Coffee'
# {'building': '115',
#  'coord': [-74.01143259999999, 40.708882],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Bank Of Nova Scotia Cafe'
# {'building': '250',
#  'coord': [-74.01556699999999, 40.7141115],
#  'street': 'Vesey Street',
#  'zipcode': '10281'}
# 'Merrill Lynch Conference Center'
# {'building': '250',
#  'coord': [-74.01556699999999, 40.7141115],
#  'street': 'Vesey Street',
#  'zipcode': '10281'}
# 'Stage Door Deli'
# {'building': '26',
#  'coord': [-74.0097128, 40.7121042],
#  'street': 'Vesey Street',
#  'zipcode': '10007'}
# "Dunkin' Donuts"
# {'building': '2',
#  'coord': [-74.0101388, 40.71000129999999],
#  'street': 'Cortlandt Street',
#  'zipcode': '10007'}
# 'Pret A Manger'
# {'building': '179',
#  'coord': [-74.009982, 40.7101924],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Youge Yogurt'
# {'building': '4',
#  'coord': [-74.01012209999999, 40.7099124],
#  'street': 'Cortlandt Street',
#  'zipcode': '10007'}
# 'Pick A Bagel'
# {'building': '311',
#  'coord': [-74.0163958, 40.7105252],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# 'St George Tower'
# {'building': '103',
#  'coord': [-74.014067, 40.708377],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Pier 25 Snack Bar'
# {'building': '225',
#  'coord': [-74.0166519, 40.7121536],
#  'street': 'West Street',
#  'zipcode': '10013'}
# 'Bento Sushi'
# {'building': '173',
#  'coord': [-74.0100468, 40.7099269],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Subway (Store #38550)'
# {'building': '111',
#  'coord': [-74.0113257, 40.7085815],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Harper Collins'
# {'building': '195',
#  'coord': [-74.0095256, 40.7107975],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'B & Co Baguettes & Company'
# {'building': '195',
#  'coord': [-74.0095256, 40.7107975],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Starbucks Coffee'
# {'building': '195',
#  'coord': [-74.0095256, 40.7107975],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Southwest Ny / Black Hound'
# {'building': '301',
#  'coord': [-74.016542, 40.7103433],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# "Harry'S Italian"
# {'building': '225',
#  'coord': [-74.0147978, 40.7151304],
#  'street': 'Murray Street',
#  'zipcode': '10282'}
# 'Cafe Bravo/ Pomodoro Pizza/Planet Gyro'
# {'building': '94',
#  'coord': [-74.013824, 40.708121],
#  'street': 'Greenwich Street',
#  'zipcode': '10006'}
# 'Juice Press'
# {'building': '83',
#  'coord': [-74.0109331, 40.7148631],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Masterpiece Pizza'
# {'building': '2',
#  'coord': [-74.0130887, 40.7080331],
#  'street': 'Rector Street',
#  'zipcode': '10006'}
# 'El Vez'
# {'building': '259',
#  'coord': [-74.0156894, 40.714586],
#  'street': 'Vesey Street',
#  'zipcode': '10282'}
# 'Residence Inn World Trade Center'
# {'building': '170',
#  'coord': [-74.0099858, 40.7095998],
#  'street': 'Broadway',
#  'zipcode': '10038'}
# 'Picasso Pizzeria'
# {'building': '303',
#  'coord': [-74.0166532, 40.710408],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# 'Blue Smoke'
# {'building': '255',
#  'coord': [-74.0154946, 40.7148288],
#  'street': 'Vesey Street',
#  'zipcode': '10282'}
# 'Creative Juice'
# {'building': '54',
#  'coord': [-74.0100543, 40.7141901],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Pick-A-Bagel'
# {'building': '251',
#  'coord': [-74.014726, 40.7153755],
#  'street': 'Murray Street',
#  'zipcode': '10282'}
# "Mcdonald'S"
# {'building': '160',
#  'coord': [-74.00998369999999, 40.7093625],
#  'street': 'Broadway',
#  'zipcode': '10038'}
# "Dunkin' Donuts"
# {'building': '19',
#  'coord': [-74.013943, 40.7079273],
#  'street': 'Rector Street',
#  'zipcode': '10006'}
# 'Caviarteria'
# {'building': '75',
#  'coord': [-74.010537, 40.714826],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Chipotle Mexican Grill'
# {'building': '275',
#  'coord': [-74.01099169999999, 40.7151804],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# 'Kaffe 1668'
# {'building': '275',
#  'coord': [-74.01099169999999, 40.7151804],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# 'Yorganic'
# {'building': '275',
#  'coord': [-74.01099169999999, 40.7151804],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# "Baluchi'S"
# {'building': '275',
#  'coord': [-74.01099169999999, 40.7151804],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# 'Barnes And Noble Booksellers'
# {'building': '97',
#  'coord': [-74.01175099999999, 40.7156001],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Madici21 Ristorante'
# {'building': '88',
#  'coord': [-74.013832, 40.7077779],
#  'street': 'Greenwich Street',
#  'zipcode': '10006'}
# 'Tajin Restaurant'
# {'building': '85',
#  'coord': [-74.0134539, 40.7076612],
#  'street': 'Greenwich Street',
#  'zipcode': '10006'}
# 'Yorganic'
# {'building': '87',
#  'coord': [-74.0144863, 40.7078788],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Clinton Hall'
# {'building': '90',
#  'coord': [-74.01486899999999, 40.70803],
#  'street': 'Washington Street',
#  'zipcode': '10006'}
# 'Downtown Deli'
# {'building': '107',
#  'coord': [-74.00920839999999, 40.7132925],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Conrad New York'
# {'building': '102',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Union Square Events'
# {'building': '102',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Conrad New York Main Kitchen'
# {'building': '102',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'North End Grill'
# {'building': '102',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Wei West/Beans & Greens'
# {'building': '102-B',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Shake Shack'
# {'building': '102',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Regal Entertainment Group'
# {'building': '102',
#  'coord': [-74.0158213, 40.7149813],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Il Giglio'
# {'building': '81',
#  'coord': [-74.010521, 40.71510869999999],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Palermo Pizza'
# {'building': '61',
#  'coord': [-74.0098493, 40.7144571],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Warren 77'
# {'building': '77',
#  'coord': [-74.0103936, 40.7150286],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Starbucks Coffee'
# {'building': '110',
#  'coord': [-74.0092858, 40.7135918],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Corner Gourmet Ii'
# {'building': '66',
#  'coord': [-74.010069, 40.7147337],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# 'Mulberry & Vine'
# {'building': '73',
#  'coord': [-74.0102352, 40.7149613],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Mangez Avec Moi'
# {'building': '7173',
#  'coord': [-74.0099177, 40.7146687],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# 'Saleya'
# {'building': '65',
#  'coord': [-74.0097816, 40.7145348],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# 'Harper Collins'
# {'building': '140',
#  'coord': [-74.01014839999999, 40.7086662],
#  'street': 'Broadway',
#  'zipcode': '10005'}
# 'Brown Brothers Cafeteria'
# {'building': '140',
#  'coord': [-74.01014839999999, 40.7086662],
#  'street': 'Broadway',
#  'zipcode': '10005'}
# "Ashby'S Specialty"
# {'building': '120',
#  'coord': [-74.01065899999999, 40.7082118],
#  'street': 'Broadway',
#  'zipcode': '10005'}
# 'The Capital Grille #8039'
# {'building': '120',
#  'coord': [-74.01065899999999, 40.7082118],
#  'street': 'Broadway',
#  'zipcode': '10005'}
# 'New York Dolls'
# {'building': '59',
#  'coord': [-74.00968449999999, 40.7145114],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Subway'
# {'building': '51',
#  'coord': [-74.00951599999999, 40.7143257],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# "Champ'S Deli"
# {'building': '71',
#  'coord': [-74.01229450000001, 40.7074764],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Bean N Bean Corp.'
# {'building': '71',
#  'coord': [-74.01229450000001, 40.7074764],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# "My Belly'S Playlist"
# {'building': '57',
#  'coord': [-74.0096063, 40.714478],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'The Cricketers Arms'
# {'building': '57',
#  'coord': [-74.0096063, 40.714478],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Banh Mi Veitnamese Sandwiches'
# {'building': '73',
#  'coord': [-74.0098208, 40.7147641],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# 'Coco Fresh Tea & Juice'
# {'building': '12',
#  'coord': [-74.0091249, 40.7098261],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Go Go Curry'
# {'building': '12',
#  'coord': [-74.0091249, 40.7098261],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Gelato Ti Amo'
# {'building': '12',
#  'coord': [-74.0091249, 40.7098261],
#  'street': 'John Street',
#  'zipcode': '10038'}
# '27 Shinjuku Sushi Inc'
# {'building': '27',
#  'coord': [-74.00892689999999, 40.7133533],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Bangal Curry'
# {'building': '27',
#  'coord': [-74.00892689999999, 40.7133533],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Raccoon Lodge'
# {'building': '59',
#  'coord': [-74.0095812, 40.71463749999999],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Bank Of New York Cafe'
# {'building': '1',
#  'coord': [-74.0116385, 40.707491],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Bank Of New York'
# {'building': '1',
#  'coord': [-74.0116385, 40.707491],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'The Bank Of New York'
# {'building': '1',
#  'coord': [-74.0116385, 40.707491],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Jupioca Inc'
# {'building': '113',
#  'coord': [-74.0089328, 40.71362730000001],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Inatesso Cafe Casano'
# {'building': '38',
#  'coord': [-74.0154227, 40.7078824],
#  'street': 'West Street',
#  'zipcode': '10004'}
# 'Elixir'
# {'building': '212',
#  'coord': [-74.01478089999999, 40.7160369],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'A La Saigon'
# {'building': '8',
#  'coord': [-74.00934699999999, 40.709193],
#  'street': 'Liberty Place',
#  'zipcode': '10005'}
# "Lenny'S Ultimate Sandwich"
# {'building': '25',
#  'coord': [-74.0087901, 40.7133206],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Oliva Gourmet'
# {'building': '225',
#  'coord': [-74.0085268, 40.71196399999999],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# "Mariachi'S Restaurant"
# {'building': '61',
#  'coord': [-74.0095802, 40.7147616],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Brasserie Les Halles'
# {'building': '15',
#  'coord': [-74.00880699999999, 40.710119],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Aroy Dee Thai Kitchen'
# {'building': '20',
#  'coord': [-74.00899930000001, 40.7096613],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Bits Bite & Baguettes'
# {'building': '22',
#  'coord': [-74.00856530000001, 40.7127305],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Variety Cafe'
# {'building': '65',
#  'coord': [-74.0123851, 40.7072227],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Benares'
# {'building': '45',
#  'coord': [-74.0091369, 40.7142472],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Woodrows'
# {'building': '43',
#  'coord': [-74.0090766, 40.7141797],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Le Pain Quotidien'
# {'building': '2',
#  'coord': [-74.0160502, 40.71546439999999],
#  'street': 'River Terrace',
#  'zipcode': '10282'}
# 'Barleycorn'
# {'building': '23',
#  'coord': [-74.00863199999999, 40.713352],
#  'street': 'Park Pl',
#  'zipcode': '10007'}
# 'Starbucks Coffee'
# {'building': '55',
#  'coord': [-74.009407, 40.7088048],
#  'street': 'Liberty Street',
#  'zipcode': '10005'}
# 'Koodo Sushi'
# {'building': '55',
#  'coord': [-74.009407, 40.7088048],
#  'street': 'Liberty Street',
#  'zipcode': '10005'}
# 'Pound And Pence'
# {'building': '55',
#  'coord': [-74.009407, 40.7088048],
#  'street': 'Liberty Street',
#  'zipcode': '10005'}
# "Papa John'S"
# {'building': '21',
#  'coord': [-74.0090051, 40.7093658],
#  'street': 'Maiden Lane',
#  'zipcode': '10038'}
# 'Dunkin Donuts'
# {'building': '130',
#  'coord': [-74.0089184, 40.7140849],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Dunkin Donuts'
# {'building': '49',
#  'coord': [-74.00930249999999, 40.7089185],
#  'street': 'Nassau Street',
#  'zipcode': '10005'}
# '22 Thai Cuisine'
# {'building': '22',
#  'coord': [-74.0091285, 40.7091424],
#  'street': 'Maiden Lane',
#  'zipcode': '10038'}
# 'Wogies Bar & Grill'
# {'building': '44',
#  'coord': [-74.01350029999999, 40.707037],
#  'street': 'Trinity Pl',
#  'zipcode': '10006'}
# 'The Irish American'
# {'building': '17',
#  'coord': [-74.008657, 40.710034],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Green Power Cafe @Equinox'
# {'building': '14',
#  'coord': [-74.0108283, 40.7075827],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Holiday Inn New York City - Wall Street'
# {'building': '51',
#  'coord': [-74.0092289, 40.7089607],
#  'street': 'Nassau Street',
#  'zipcode': '10005'}
# 'Subway'
# {'building': '23',
#  'coord': [-74.00895469999999, 40.7093329],
#  'street': 'Maiden Lane',
#  'zipcode': '10038'}
# 'Gee Whiz'
# {'building': '295',
#  'coord': [-74.0108091, 40.7160466],
#  'street': 'Greenwich Street',
#  'zipcode': '10007'}
# 'Starbucks Coffee'
# {'building': '233',
#  'coord': [-74.0083234, 40.7124877],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Washington Market Tavern'
# {'building': '41',
#  'coord': [-74.0089512, 40.7142738],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Diwan-E- Khaas'
# {'building': '53',
#  'coord': [-74.0091352, 40.7090346],
#  'street': 'Nassau Street',
#  'zipcode': '10005'}
# 'Cafe Tomato'
# {'building': '142',
#  'coord': [-74.0084842, 40.7103597],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# "Lilly O'Briens"
# {'building': '18',
#  'coord': [-74.0085019, 40.713369],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'New York Mercantile Exchange'
# {'building': '1',
#  'coord': [-74.0169995, 40.7147163],
#  'street': 'North End Avenue',
#  'zipcode': '10281'}
# 'Famous Famiglia Pizza'
# {'building': '26',
#  'coord': [-74.0086065, 40.7137002],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Remix'
# {'building': '24',
#  'coord': [-74.0085532, 40.713676],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'J R Sushi'
# {'building': '86A',
#  'coord': [-74.0096126, 40.7152803],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# 'Palm Restaurant'
# {'building': '200',
#  'coord': [-74.0122865, 40.7166708],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Kitchenette'
# {'building': '156',
#  'coord': [-74.01018429999999, 40.7157873],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Toasties'
# {'building': '25',
#  'coord': [-74.0085713, 40.7098097],
#  'street': 'John Street',
#  'zipcode': '10038'}
# '59 China'
# {'building': '59',
#  'coord': [-74.0088627, 40.7092384],
#  'street': 'Nassau St',
#  'zipcode': '10038'}
# 'Friendly Pizzeria'
# {'building': '59',
#  'coord': [-74.0088627, 40.7092384],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# "Zucker'S Bagels And Smoked Fish"
# {'building': '146',
#  'coord': [-74.00985849999999, 40.7155442],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Cafe Exchange'
# {'building': '49',
#  'coord': [-74.0133214, 40.7068236],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Sabor De Mexico'
# {'building': '11',
#  'coord': [-74.0082771, 40.7130634],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Little Italy Pizza'
# {'building': '11',
#  'coord': [-74.0082771, 40.7130634],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Best Of The Best Delicatessen'
# {'building': '11',
#  'coord': [-74.0082771, 40.7130634],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'Le Pain Quotidien'
# {'building': '81',
#  'coord': [-74.0093072, 40.7150388],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# 'Health King'
# {'building': '65',
#  'coord': [-74.0086743, 40.7094986],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Jamba Juice'
# {'building': '88',
#  'coord': [-74.0096516, 40.7154091],
#  'street': 'West Broadway',
#  'zipcode': '10007'}
# "Cafe Amore'S Restaurant"
# {'building': '14751',
#  'coord': [-74.01136939999999, 40.7164914],
#  'street': 'Chambers Street',
#  'zipcode': '10013'}
# "Mcdonald'S"
# {'building': '167',
#  'coord': [-74.0106828, 40.71618410000001],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Sale & Pepe'
# {'building': '1',
#  'coord': [-74.0127104, 40.7067796],
#  'street': 'Exchange Plaza',
#  'zipcode': '10006'}
# 'The Diner'
# {'building': '75',
#  'coord': [-74.00840099999999, 40.709871],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Takahachi Bakery'
# {'building': '25',
#  'coord': [-74.00839669999999, 40.71386340000001],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Muscle Maker Grill'
# {'building': '10',
#  'coord': [-74.0081867, 40.7133359],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'D Elici'
# {'building': '71',
#  'coord': [-74.00840649999999, 40.7096829],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Little Park'
# {'building': '85',
#  'coord': [-74.0091826, 40.7151439],
#  'street': 'W Broadway',
#  'zipcode': '10007'}
# 'Drill Fitness'
# {'building': '136',
#  'coord': [-74.0085276, 40.7141951],
#  'street': 'Church St',
#  'zipcode': '10007'}
# 'Blimpie'
# {'building': '69',
#  'coord': [-74.0084735, 40.7094988],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Agoda Asian Cuisine'
# {'building': '8',
#  'coord': [-74.0081399, 40.71329980000001],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'China Chalet'
# {'building': '47',
#  'coord': [-74.01303759999999, 40.70661],
#  'street': 'Broadway',
#  'zipcode': '10006'}
# 'Inatesso Pizzabar Casano'
# {'building': '28',
#  'coord': [-74.0156983, 40.7072681],
#  'street': 'West Street',
#  'zipcode': '10004'}
# 'Subway'
# {'building': '153',
#  'coord': [-74.0099578, 40.7159798],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Starbucks Coffee'
# {'building': '130',
#  'coord': [-74.0080866, 40.7103049],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Macaron Boutique Llc'
# {'building': '303',
#  'coord': [-74.0107106, 40.71646560000001],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# "Dunkin' Donuts"
# {'building': '5',
#  'coord': [-74.0079564, 40.7128255],
#  'street': 'Park Place',
#  'zipcode': '10007'}
# 'New York Stock Exchange Executive Services'
# {'building': '11',
#  'coord': [-74.0111421, 40.7069226],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'New York Stock Exchange'
# {'building': '11',
#  'coord': [-74.0111421, 40.7069226],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Manhattan Proper'
# {'building': '6',
#  'coord': [-74.0080433, 40.7132703],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Dirty Bird To Go'
# {'building': '155',
#  'coord': [-74.0099709, 40.716076],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# "Wendy'S"
# {'building': '85',
#  'coord': [-74.00806159999999, 40.7101566],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Baba Ghanouge'
# {'building': '143',
#  'coord': [-74.0079181, 40.7106447],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Mudville Saloon'
# {'building': '126',
#  'coord': [-74.00893959999999, 40.7151413],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Pita Express'
# {'building': '15',
#  'coord': [-74.0077811, 40.7110299],
#  'street': 'Ann Street',
#  'zipcode': '10038'}
# 'United Federation Of Teachers'
# {'building': '52',
#  'coord': [-74.01227399999999, 40.706483],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Ecco Restaurant'
# {'building': '124',
#  'coord': [-74.00885, 40.7151357],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Darkhorse'
# {'building': '17',
#  'coord': [-74.00803379999999, 40.7137041],
#  'street': 'Murray Street',
#  'zipcode': '10007'}
# 'Acappella Restaurant'
# {'building': '1',
#  'coord': [-74.00939799999999, 40.715763],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# 'Subway'
# {'building': '250',
#  'coord': [-74.00780019999999, 40.7129744],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Bravo Kosher Pizza'
# {'building': '17',
#  'coord': [-74.0139629, 40.7064257],
#  'street': 'Trinity Place',
#  'zipcode': '10006'}
# 'Zaitzeff'
# {'building': '72',
#  'coord': [-74.00812189999999, 40.7095929],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Sandwich House Italian Restaurant'
# {'building': '17',
#  'coord': [-74.0077002, 40.7110027],
#  'street': 'Ann Street',
#  'zipcode': '10038'}
# 'Sabor De Mexico'
# {'building': '76',
#  'coord': [-74.0080705, 40.7096285],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Vivi Bubble Tea'
# {'building': '39',
#  'coord': [-74.0081333, 40.7094561],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Lavazza Cafe Per Wes'
# {'building': '99',
#  'coord': [-74.0077594, 40.7104929],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# "Quynh'S Vietnamese Sandwiches"
# {'building': '99',
#  'coord': [-74.0077594, 40.7104929],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Reade Street Pub & Kitchen'
# {'building': '135',
#  'coord': [-74.00977089999999, 40.7161935],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# 'China Red Gourment'
# {'building': '118',
#  'coord': [-74.0086053, 40.715012],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Stamina Grill & Juice Bar'
# {'building': '80',
#  'coord': [-74.00793089999999, 40.7098225],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# "Mike'S Noodle House"
# {'building': '80',
#  'coord': [-74.00793089999999, 40.7098225],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'New York Vintners'
# {'building': '21',
#  'coord': [-74.007903, 40.71387319999999],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Pret A Manger'
# {'building': '50',
#  'coord': [-74.01245469999999, 40.7062246],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Blarney Stone'
# {'building': '11',
#  'coord': [-74.0137007, 40.7062029],
#  'street': 'Trinity Place',
#  'zipcode': '10006'}
# 'Mbj Downtown'
# {'building': '199',
#  'coord': [-74.01217799999999, 40.717367],
#  'street': 'Chambers Street',
#  'zipcode': '10013'}
# 'Pisillo Italian Panini'
# {'building': '97',
#  'coord': [-74.0075568, 40.7106696],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Starbucks Coffee'
# {'building': '95',
#  'coord': [-74.0088763, 40.7155873],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'The Patriot Saloon'
# {'building': '110',
#  'coord': [-74.0083173, 40.7148709],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Financier Patisserie'
# {'building': '90',
#  'coord': [-74.007679, 40.710078],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'The Financier Patisserie'
# {'building': '3-4',
#  'coord': [-74.0178269, 40.7149764],
#  'street': 'World Financial Center',
#  'zipcode': '10281'}
# 'Richards Kibbie & Orbe Llp'
# {'building': '1',
#  'coord': [-74.0178269, 40.7149764],
#  'street': 'World Financial Center',
#  'zipcode': '10281'}
# "P.J. Clarke'S On The Hudson"
# {'building': '4',
#  'coord': [-74.0178269, 40.7149764],
#  'street': 'World Financial Center',
#  'zipcode': '10281'}
# 'Da Claudio'
# {'building': '21',
#  'coord': [-74.0074727, 40.7108372],
#  'street': 'Ann St',
#  'zipcode': '10038'}
# 'Imperial Coffee House'
# {'building': '108',
#  'coord': [-74.0082408, 40.7148452],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# "Dunkin' Donuts"
# {'building': '122',
#  'coord': [-74.00761589999999, 40.7099729],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Tarallucci E Vino'
# {'building': '42',
#  'coord': [-74.0126296, 40.7060086],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# "Mary'S Dominican Cake"
# {'building': '42',
#  'coord': [-74.0126296, 40.7060086],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# "Gregory'S Coffee"
# {'building': '42',
#  'coord': [-74.0126296, 40.7060086],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Hallmark Deli'
# {'building': '455',
#  'coord': [-74.014517, 40.717478],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'The Hallmark Of Battery Park City- Dining Room'
# {'building': '455',
#  'coord': [-74.014517, 40.717478],
#  'street': 'North End Avenue',
#  'zipcode': '10282'}
# 'Salaam Bombay'
# {'building': '319',
#  'coord': [-74.01049809999999, 40.71705499999999],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Ward Iii'
# {'building': '111',
#  'coord': [-74.00871029999999, 40.7157247],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# 'Gran Morsi'
# {'building': '22',
#  'coord': [-74.0077659, 40.7143151],
#  'street': 'Warren Street',
#  'zipcode': '10007'}
# 'Bluestone Lane Coffee'
# {'building': '30',
#  'coord': [-74.01153459999999, 40.7061121],
#  'street': 'Broad',
#  'zipcode': '10004'}
# 'Subway'
# {'building': '30',
#  'coord': [-74.01153459999999, 40.7061121],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Champ Gourmet'
# {'building': '30',
#  'coord': [-74.01153459999999, 40.7061121],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Mark Forgione'
# {'building': '134',
#  'coord': [-74.00956699999999, 40.7165262],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# 'Milbank Tweed Hadley & Mccloy'
# {'building': '1',
#  'coord': [-74.0087694, 40.70776619999999],
#  'street': 'Chase Manhattan Plaza',
#  'zipcode': '10005'}
# 'J P Morgan Chase Cafeteria'
# {'building': '1',
#  'coord': [-74.0087694, 40.70776619999999],
#  'street': 'Chase Manhattan Plaza',
#  'zipcode': '10005'}
# 'Dona Bella  Pizza'
# {'building': '154',
#  'coord': [-74.0080141, 40.7148489],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'West 79Th Street Boat Basin Cafe'
# {'building': '',
#  'coord': [-74.0163793, 40.7167671],
#  'street': 'Hudson River',
#  'zipcode': '10282'}
# 'Bento Nouveau'
# {'building': '32',
#  'coord': [-74.0127775, 40.7058397],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Stir Cafe'
# {'building': '32',
#  'coord': [-74.0127775, 40.7058397],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Sazon'
# {'building': '105',
#  'coord': [-74.008493, 40.715618],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# "Dunkin' Donuts, Baskin Robbins"
# {'building': '100',
#  'coord': [-74.0078192, 40.7146326],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'El Toro Mexican Grill'
# {'building': '69',
#  'coord': [-74.0122263, 40.7058609],
#  'street': 'New Street',
#  'zipcode': '10004'}
# 'The Grotto'
# {'building': '69',
#  'coord': [-74.0122263, 40.7058609],
#  'street': 'New Street',
#  'zipcode': '10004'}
# ''
# {'building': '40',
#  'coord': [-74.0095219, 40.7069772],
#  'street': 'Wall St',
#  'zipcode': '10005'}
# 'The Country Cafe'
# {'building': '40',
#  'coord': [-74.0095219, 40.7069772],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Test'
# {'building': '59',
#  'coord': [-74.00790599999999, 40.708772],
#  'street': 'Maiden Lane',
#  'zipcode': '10038'}
# 'Miramar'
# {'building': '21',
#  'coord': [-74.0178918, 40.7081658],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# 'Liberty View Chinese Restaurant'
# {'building': '21',
#  'coord': [-74.0178918, 40.7081658],
#  'street': 'South End Avenue',
#  'zipcode': '10280'}
# 'Crumbs Bake Shop'
# {'building': '40',
#  'coord': [-74.011808, 40.7059085],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Reserve Cut'
# {'building': '40',
#  'coord': [-74.011808, 40.7059085],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# "Bobby Van'S Steakhouse"
# {'building': '25',
#  'coord': [-74.0111372, 40.7060887],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Saffron Indian Cuisine'
# {'building': '98',
#  'coord': [-74.00774129999999, 40.71461],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Potbelly Sandwich Shop'
# {'building': '127',
#  'coord': [-74.0072501, 40.7102428],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Roc Restaurant'
# {'building': '323',
#  'coord': [-74.010475, 40.7172636],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Gigino Trattoria'
# {'building': '323',
#  'coord': [-74.010475, 40.7172636],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# "Sophie'S Cuban Cuisine"
# {'building': '96',
#  'coord': [-74.0076595, 40.7145744],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Long Island Bagel Cafe'
# {'building': '125',
#  'coord': [-74.007166, 40.710222],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Racines Nyc Llc'
# {'building': '94',
#  'coord': [-74.0075834, 40.7145385],
#  'street': 'Chambers St',
#  'zipcode': '10007'}
# 'Ninja Restaurant'
# {'building': '25',
#  'coord': [-74.009407, 40.7168467],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# '121 Fulton Street'
# {'building': '121',
#  'coord': [-74.0070554, 40.7100732],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Kaede Japanese Restaurant'
# {'building': '90',
#  'coord': [-74.0074185, 40.7144942],
#  'street': 'Chambers St',
#  'zipcode': '10007'}
# 'Lotus Blue'
# {'building': '110',
#  'coord': [-74.0084612, 40.7160585],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# 'Cipriani 25 Broadway'
# {'building': '25',
#  'coord': [-74.0139121, 40.7055177],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'By Suzette French Crepes'
# {'building': '86',
#  'coord': [-74.0072617, 40.7144168],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Starbucks Coffee'
# {'building': '38',
#  'coord': [-74.0066803, 40.7115866],
#  'street': 'Park Row',
#  'zipcode': '10038'}
# 'Hideaway'
# {'building': '185',
#  'coord': [-74.01027739999999, 40.7175736],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Burger King'
# {'building': '106',
#  'coord': [-74.0070071, 40.7097029],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Toyko Bay Japanese Restaurant'
# {'building': '183',
#  'coord': [-74.01020729999999, 40.7175644],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Cucina Bene Pizzeria'
# {'building': '41',
#  'coord': [-74.0102885, 40.7059882],
#  'street': 'Exchange Place',
#  'zipcode': '10005'}
# "Tribeca'S Cornerstone"
# {'building': '327',
#  'coord': [-74.0103305, 40.71763320000001],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Au Bon Pain'
# {'building': '111',
#  'coord': [-74.0068953, 40.70999219999999],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Melt Shop'
# {'building': '111',
#  'coord': [-74.0068953, 40.70999219999999],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Hale & Hearty'
# {'building': '111',
#  'coord': [-74.0068953, 40.70999219999999],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Grk Fresh Greek'
# {'building': '111',
#  'coord': [-74.0068953, 40.70999219999999],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Red Mango'
# {'building': '111',
#  'coord': [-74.0068953, 40.70999219999999],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# "Sophie'S Restaurant"
# {'building': '26',
#  'coord': [-74.01299449999999, 40.7053319],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Max Restaurant'
# {'building': '181',
#  'coord': [-74.0101342, 40.7175552],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Sole Di Capri'
# {'building': '165',
#  'coord': [-74.0075402, 40.7151466],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Sun In Bloom'
# {'building': '165',
#  'coord': [-74.0075402, 40.7151466],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Subway'
# {'building': '165',
#  'coord': [-74.0075402, 40.7151466],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Babaghanoush'
# {'building': '165',
#  'coord': [-74.0075402, 40.7151466],
#  'street': 'Church Street',
#  'zipcode': '10007'}
# 'Brushstroke (30 Hudson St)'
# {'building': '162',
#  'coord': [-74.0090342, 40.7168674],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Ann Street Hotel Llc'
# {'building': '49',
#  'coord': [-74.00677929999999, 40.7102943],
#  'street': 'Ann Street',
#  'zipcode': '10038'}
# 'Wanted Pizza'
# {'building': '104',
#  'coord': [-74.00693079999999, 40.7096482],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Subway'
# {'building': '11',
#  'coord': [-74.0139114, 40.7053128],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Cafe 11'
# {'building': '11',
#  'coord': [-74.0139114, 40.7053128],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Cafe Plaza Deli'
# {'building': '11',
#  'coord': [-74.0139114, 40.7053128],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Tribeca Treats'
# {'building': '94',
#  'coord': [-74.0078645, 40.7157322],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# 'Bluespoon Coffee'
# {'building': '76',
#  'coord': [-74.00704379999999, 40.7143089],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Bikini Bar'
# {'building': '148',
#  'coord': [-74.008223, 40.716223],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'The Bailey'
# {'building': '52',
#  'coord': [-74.0089239, 40.706708],
#  'street': 'William Street',
#  'zipcode': '10005'}
# 'Bouley'
# {'building': '161163',
#  'coord': [-74.00873849999999, 40.7167499],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Magic Mix Juicery'
# {'building': '102',
#  'coord': [-74.0068636, 40.7096409],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Nyc Yogurt'
# {'building': '102',
#  'coord': [-74.0068636, 40.7096409],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# "Dunkin' Donuts"
# {'building': '132',
#  'coord': [-74.0065454, 40.7109854],
#  'street': 'Nassau Street',
#  'zipcode': '10038'}
# 'Dunkin Donuts'
# {'building': '50',
#  'coord': [-74.0086171, 40.7069298],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Koyzina Kafe'
# {'building': '62',
#  'coord': [-74.00844099999999, 40.707058],
#  'street': 'William Street',
#  'zipcode': '10005'}
# 'Oriental Express'
# {'building': '62',
#  'coord': [-74.00844099999999, 40.707058],
#  'street': 'William Street',
#  'zipcode': '10005'}
# 'Nish Nush'
# {'building': '88',
#  'coord': [-74.007705, 40.7157109],
#  'street': 'Reade Street',
#  'zipcode': '10013'}
# 'Blue Spoon'
# {'building': '90',
#  'coord': [-74.0075488, 40.7081095],
#  'street': 'William Street',
#  'zipcode': '10038'}
# 'Financier Patisserie'
# {'building': '10',
#  'coord': [-74.0080725, 40.7073797],
#  'street': 'Liberty Street',
#  'zipcode': '10005'}
# 'Blimpie'
# {'building': '40',
#  'coord': [-74.0102663, 40.7057236],
#  'street': 'Exchange Place',
#  'zipcode': '10005'}
# 'Irish Punt'
# {'building': '40',
#  'coord': [-74.0102663, 40.7057236],
#  'street': 'Exchange Place',
#  'zipcode': '10005'}
# 'Carvel Ice Cream'
# {'building': '9',
#  'coord': [-74.0142069, 40.7051869],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# 'Benton Cafe'
# {'building': '123',
#  'coord': [-74.0068984, 40.7092395],
#  'street': 'William St',
#  'zipcode': '10038'}
# "Dave'S Hoagies"
# {'building': '26',
#  'coord': [-74.0083887, 40.7070189],
#  'street': 'Cedar Street',
#  'zipcode': '10005'}
# 'Pakistan Tea House'
# {'building': '176',
#  'coord': [-74.0076428, 40.7157261],
#  'street': 'Church Street',
#  'zipcode': '10013'}
# 'Weather Up'
# {'building': '159',
#  'coord': [-74.0087471, 40.7169248],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Dunkin Donuts'
# {'building': '33',
#  'coord': [-74.0120712, 40.705152],
#  'street': 'Beaver Street',
#  'zipcode': '10004'}
# 'Taco House'
# {'building': '178',
#  'coord': [-74.0076053, 40.7156902],
#  'street': 'Church Street',
#  'zipcode': '10013'}
# 'Church Street Kitchen'
# {'building': '178',
#  'coord': [-74.0076053, 40.7156902],
#  'street': 'Church Street',
#  'zipcode': '10013'}
# 'Taz Cafe'
# {'building': '54',
#  'coord': [-74.0085587, 40.7067779],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Pret A Manger'
# {'building': '60',
#  'coord': [-74.0118361, 40.7051454],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Au Bon Pain'
# {'building': '60',
#  'coord': [-74.0118361, 40.7051454],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'The Beekman'
# {'building': '15',
#  'coord': [-74.0063787, 40.7108898],
#  'street': 'Beekman Street',
#  'zipcode': '10038'}
# 'Scalini Fedeli'
# {'building': '165',
#  'coord': [-74.009317, 40.7174312],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Simit & Smith'
# {'building': '100',
#  'coord': [-74.0072149, 40.7084158],
#  'street': 'William Street',
#  'zipcode': '10038'}
# 'Starbucks Coffee'
# {'building': '100',
#  'coord': [-74.0072149, 40.7084158],
#  'street': 'William Street',
#  'zipcode': '10038'}
# 'Sushi Of Gari Tribeca'
# {'building': '130',
#  'coord': [-74.008468, 40.7167708],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# "Oren'S Daily Roast"
# {'building': '135',
#  'coord': [-74.00671419999999, 40.7094706],
#  'street': 'William Street',
#  'zipcode': '10038'}
# 'Pita Press'
# {'building': '25',
#  'coord': [-74.0082771, 40.7069901],
#  'street': 'Cedar Street',
#  'zipcode': '10005'}
# 'Khe-Yo'
# {'building': '157',
#  'coord': [-74.00858699999999, 40.716906],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Lane Deli & Catering'
# {'building': '75',
#  'coord': [-74.0075542, 40.7077614],
#  'street': 'Maiden Lane',
#  'zipcode': '10038'}
# "Jim Brady'S Restaurant"
# {'building': '75',
#  'coord': [-74.0075542, 40.7077614],
#  'street': 'Maiden Lane',
#  'zipcode': '10038'}
# 'Hale & Hearty Soups'
# {'building': '55',
#  'coord': [-74.0108765, 40.7052927],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Cosi Cafe'
# {'building': '55',
#  'coord': [-74.0108765, 40.7052927],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Starbucks Coffee #7416'
# {'building': '55',
#  'coord': [-74.0108765, 40.7052927],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Ise Restaurant'
# {'building': '56',
#  'coord': [-74.00838089999999, 40.70677209999999],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Cipriani Club 55'
# {'building': '55',
#  'coord': [-74.0092784, 40.7060535],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Cipriani'
# {'building': '55',
#  'coord': [-74.0092784, 40.7060535],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Church Publick'
# {'building': '78',
#  'coord': [-74.0072035, 40.7154284],
#  'street': 'Reade Street',
#  'zipcode': '10007'}
# 'The Hummus & Pita Co.'
# {'building': '79',
#  'coord': [-74.0067897, 40.7146694],
#  'street': 'Chambers Street',
#  'zipcode': '10007'}
# 'Petite Abeille'
# {'building': '134',
#  'coord': [-74.008419, 40.716914],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'Cafe De Novo'
# {'building': '94 1/2',
#  'coord': [-74.0150439, 40.7051391],
#  'street': 'Greenwich St',
#  'zipcode': '10006'}
# 'Mehtaphor'
# {'building': '130',
#  'coord': [-74.00744399999999, 40.715858],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Checkers'
# {'building': '77',
#  'coord': [-74.00670199999999, 40.714593],
#  'street': 'Chambers St',
#  'zipcode': '10007'}
# 'Chipotle Mexican Grill'
# {'building': '101',
#  'coord': [-74.0064049, 40.7098119],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Kenyon & Kenyon Cafeteria'
# {'building': '1',
#  'coord': [-74.0145347, 40.7049443],
#  'street': 'Broadway',
#  'zipcode': '10004'}
# "Edward'S"
# {'building': '136',
#  'coord': [-74.00837299999999, 40.716973],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'Burger King'
# {'building': '16',
#  'coord': [-74.0124913, 40.704817],
#  'street': 'Beaver Street',
#  'zipcode': '10004'}
# "Georgio'S Pizzeria"
# {'building': '20',
#  'coord': [-74.0123134, 40.7048238],
#  'street': 'Beaver Street',
#  'zipcode': '10004'}
# "Yip'S Restaurant"
# {'building': '18',
#  'coord': [-74.01238599999999, 40.7048158],
#  'street': 'Beaver Street',
#  'zipcode': '10004'}
# 'Bar Cyrk Nyc'
# {'building': '50',
#  'coord': [-74.0087702, 40.7173558],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# "Trader'S Express Deli"
# {'building': '22',
#  'coord': [-74.0121932, 40.704813],
#  'street': 'Beaver Street',
#  'zipcode': '10004'}
# 'Chickpea'
# {'building': '110',
#  'coord': [-74.0066886, 40.7088758],
#  'street': 'William Street',
#  'zipcode': '10038'}
# 'Takahachi Tribeca'
# {'building': '145',
#  'coord': [-74.00791699999999, 40.716593],
#  'street': 'Duane Street',
#  'zipcode': '10013'}
# 'Liberatos Pizza'
# {'building': '17',
#  'coord': [-74.0079385, 40.7069636],
#  'street': 'Cedar Street',
#  'zipcode': '10005'}
# "Tiny'S And The Bar Upstairs"
# {'building': '135',
#  'coord': [-74.007994, 40.716698],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'New Fresco Tortillos Iii'
# {'building': '63',
#  'coord': [-74.00666129999999, 40.7147811],
#  'street': 'Reade Street',
#  'zipcode': '10007'}
# 'Hamachi Sushi'
# {'building': '63A',
#  'coord': [-74.00666129999999, 40.7147811],
#  'street': 'Reade Street',
#  'zipcode': '10007'}
# 'Down Town Association'
# {'building': '60',
#  'coord': [-74.0081545, 40.7067097],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'New Sun Cafe Japanese Cuisine Inc'
# {'building': '67',
#  'coord': [-74.0067626, 40.7150129],
#  'street': 'Reade Street',
#  'zipcode': '10007'}
# "Sarabeth'S"
# {'building': '339',
#  'coord': [-74.0102534, 40.7183216],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Tre Sorelle'
# {'building': '61',
#  'coord': [-74.0066253, 40.7147527],
#  'street': 'Reade Street',
#  'zipcode': '10007'}
# "Domino'S Pizza"
# {'building': '181',
#  'coord': [-74.0070818, 40.715609],
#  'street': 'Church Street',
# ...
#  'coord': [-74.0118845, 40.70374289999999],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Gigino At Wagner Park'
# {'building': '20',
#  'coord': [-74.01756189999999, 40.7049736],
#  'street': 'Battery Place',
#  'zipcode': '10004'}
# 'Route 66 American Bbq'
# {'building': '79',
#  'coord': [-74.010393, 40.7040863],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Open Door Gastropub'
# {'building': '110',
#  'coord': [-74.0060373, 40.7076634],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Stone Street Tavern'
# {'building': '85',
#  'coord': [-74.0101344, 40.7041613],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Aiko Sushi Japanese Restaurant (Jinshu Sushi)'
# {'building': '164',
#  'coord': [-74.0074034, 40.7058765],
#  'street': 'Pearl Street',
#  'zipcode': '10005'}
# 'Ulysses'
# {'building': '91',
#  'coord': [-74.01010440000002, 40.7041181],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'The Full Shilling'
# {'building': '160',
#  'coord': [-74.0074941, 40.7057352],
#  'street': 'Pearl Street',
#  'zipcode': '10005'}
# 'Yogurt In Love'
# {'building': '160',
#  'coord': [-74.0074941, 40.7057352],
#  'street': 'Pearl Street',
#  'zipcode': '10005'}
# 'Thalassa'
# {'building': '179',
#  'coord': [-74.00954209999999, 40.7193048],
#  'street': 'Franklin Street',
#  'zipcode': '10013'}
# 'Starbucks Coffee'
# {'building': '110',
#  'coord': [-74.0088049, 40.7046907],
#  'street': 'Pearl Street',
#  'zipcode': '10005'}
# 'The Original Soupman/ Ranch 1'
# {'building': '110',
#  'coord': [-74.0088049, 40.7046907],
#  'street': 'Pearl Street',
#  'zipcode': '10005'}
# 'Alfanoose'
# {'building': '64',
#  'coord': [-74.00536090000001, 40.708721],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# "Ruben'S Empanadas"
# {'building': '64',
#  'coord': [-74.00536090000001, 40.708721],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Dunkin Donuts'
# {'building': '64',
#  'coord': [-74.00536090000001, 40.708721],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Flavors'
# {'building': '27',
#  'coord': [-74.012872, 40.703472],
#  'street': 'Whitehall Street',
#  'zipcode': '10004'}
# 'Subway/Carvel'
# {'building': '112',
#  'coord': [-74.0059059, 40.7075821],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Dina Rata At Andaz Wall Street Hotel'
# {'building': '75',
#  'coord': [-74.0080186, 40.70517890000001],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Tamarind Tribeca'
# {'building': '99',
#  'coord': [-74.0090266, 40.7191069],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# 'Battery Gardens Restaurant'
# {'building': '1',
#  'coord': [-74.0135458, 40.7034442],
#  'street': 'Battery Park Plaza',
#  'zipcode': '10004'}
# 'Hughes Hubbard & Reed Llp'
# {'building': '1',
#  'coord': [-74.0135458, 40.7034442],
#  'street': 'Battery Park Plaza',
#  'zipcode': '10004'}
# "Lenny'S Hanover, Llc"
# {'building': '10',
#  'coord': [-74.008884, 40.704546],
#  'street': 'Hanover Square',
#  'zipcode': '10005'}
# 'Complete Body'
# {'building': '10',
#  'coord': [-74.008884, 40.704546],
#  'street': 'Hanover Square',
#  'zipcode': '10005'}
# 'Tribeca Grill'
# {'building': '375',
#  'coord': [-74.0099723, 40.7196029],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Pearl Street Diner'
# {'building': '212',
#  'coord': [-74.00617869999999, 40.7069302],
#  'street': 'Pearl Street',
#  'zipcode': '10038'}
# 'Holiday Inn Express'
# {'building': '126',
#  'coord': [-74.0072857, 40.7056213],
#  'street': 'Water Street',
#  'zipcode': '10005'}
# 'Tribeca Pizzeria'
# {'building': '378',
#  'coord': [-74.010465, 40.7198789],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Guardian Life Employee Cafeteria'
# {'building': '7',
#  'coord': [-74.00973950000001, 40.7039923],
#  'street': 'Hanover Square',
#  'zipcode': '10004'}
# 'Robusta Espresso Bar'
# {'building': '7',
#  'coord': [-74.00973950000001, 40.7039923],
#  'street': 'Hanover Square',
#  'zipcode': '10004'}
# 'Cafe Water'
# {'building': '130',
#  'coord': [-74.0071785, 40.7056884],
#  'street': 'Water Street',
#  'zipcode': '10005'}
# 'Subway'
# {'building': '122',
#  'coord': [-74.007334, 40.70554],
#  'street': 'Water Street',
#  'zipcode': '10005'}
# 'CafÉ Gusto'
# {'building': '111',
#  'coord': [-74.0055508, 40.7078424],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Grand Banks'
# {'building': '',
#  'coord': [-74.0141067, 40.7202895],
#  'street': 'Pier   25',
#  'zipcode': '10013'}
# 'Insomnia  Cooklies'
# {'building': '76',
#  'coord': [-74.0102777, 40.7037299],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Nu Sushi'
# {'building': '76',
#  'coord': [-74.0102777, 40.7037299],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Fika'
# {'building': '66',
#  'coord': [-74.0108985, 40.7035292],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Guac Star/Zigolinis'
# {'building': '66',
#  'coord': [-74.0108985, 40.7035292],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Dig Inn Seasonal Market'
# {'building': '80',
#  'coord': [-74.0067882, 40.7060144],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Starbucks Coffee'
# {'building': '80',
#  'coord': [-74.0067882, 40.7060144],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# "Chop'T Creative Salad Company"
# {'building': '80',
#  'coord': [-74.0067882, 40.7060144],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Hale & Hearty Soups'
# {'building': '80',
#  'coord': [-74.0067882, 40.7060144],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Au Bon Pain'
# {'building': '80',
#  'coord': [-74.0067882, 40.7060144],
#  'street': 'Pine Street',
#  'zipcode': '10005'}
# 'Starbucks Coffee'
# {'building': '180',
#  'coord': [-74.0073905, 40.7182039],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'Atomic Wings'
# {'building': '311',
#  'coord': [-74.0054313, 40.7156594],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Landmarc'
# {'building': '179',
#  'coord': [-74.007054, 40.717897],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'Fraunces Tavern'
# {'building': '54',
#  'coord': [-74.0113732, 40.7033722],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# "Bombay'S"
# {'building': '60',
#  'coord': [-74.01108099999999, 40.703428],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# "Shorty'S"
# {'building': '62',
#  'coord': [-74.0109628, 40.7034162],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'Locanda Verde'
# {'building': '377',
#  'coord': [-74.00985399999999, 40.7198459],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Nobu'
# {'building': '105',
#  'coord': [-74.00897599999999, 40.7194498],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# 'Nobu Next Door'
# {'building': '105',
#  'coord': [-74.00897599999999, 40.7194498],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# 'Anglers Club Of New York'
# {'building': '101',
#  'coord': [-74.0112941, 40.7032931],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'La Bellezza Pizzeria'
# {'building': '315',
#  'coord': [-74.00530719999999, 40.7157054],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Pearl Street Hampton Inn'
# {'building': '32',
#  'coord': [-74.01236449999999, 40.7031044],
#  'street': 'Pearl Street',
#  'zipcode': '10004'}
# 'New York Law School'
# {'building': '185',
#  'coord': [-74.0069736, 40.7180192],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'Da Vinci Pizza'
# {'building': '44',
#  'coord': [-74.01009599999999, 40.703603],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# "Lenny'S"
# {'building': '32',
#  'coord': [-74.01094499999999, 40.703337],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'Pranzo'
# {'building': '34',
#  'coord': [-74.01084569999999, 40.70335439999999],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'All American Deli'
# {'building': '42',
#  'coord': [-74.010173, 40.703561],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'The Dead Rabbit'
# {'building': '30',
#  'coord': [-74.0110289, 40.7033],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'Obao Noodles & Bbq'
# {'building': '38',
#  'coord': [-74.0106655, 40.7033922],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'Subway'
# {'building': '28',
#  'coord': [-74.0110885, 40.7032752],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# "Ryan Maguire'S Bar & Restaurant"
# {'building': '28',
#  'coord': [-74.00513529999999, 40.7081169],
#  'street': 'Cliff Street',
#  'zipcode': '10038'}
# "Rockwell'S"
# {'building': '105',
#  'coord': [-74.011331, 40.70319],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# "Mcdonald'S"
# {'building': '317',
#  'coord': [-74.0052218, 40.7157637],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# "Tj Byrne'S Bar"
# {'building': '77',
#  'coord': [-74.0046811, 40.7090818],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'The Best Of New York Food'
# {'building': '150',
#  'coord': [-74.0060591, 40.7064287],
#  'street': 'Water Street',
#  'zipcode': '10005'}
# 'Square Diner'
# {'building': '33',
#  'coord': [-74.00725299999999, 40.718485],
#  'street': 'Leonard Street',
#  'zipcode': '10013'}
# 'Smith & Mills'
# {'building': '71',
#  'coord': [-74.0097664, 40.7200611],
#  'street': 'North Moore Street',
#  'zipcode': '10013'}
# 'The Iron Horse'
# {'building': '32',
#  'coord': [-74.0049536, 40.7081585],
#  'street': 'Cliff Street',
#  'zipcode': '10038'}
# "Mcdonald'S"
# {'building': '52',
#  'coord': [-74.0049104, 40.7082556],
#  'street': 'Fulton Street',
#  'zipcode': '10038'}
# 'Pret A Manger'
# {'building': '319',
#  'coord': [-74.0051979, 40.715956],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Pier A'
# {'building': '22',
#  'coord': [-74.018091, 40.70436979999999],
#  'street': 'Battery Place',
#  'zipcode': '10280'}
# 'Cafe 55'
# {'building': '55',
#  'coord': [-74.0098074, 40.703465],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'Sky 55 Seasonal'
# {'building': '55',
#  'coord': [-74.0098074, 40.703465],
#  'street': 'Water Street',
#  'zipcode': '10004'}
# 'Citi Employee Cafeteria'
# {'building': '388',
#  'coord': [-74.0113978, 40.7206627],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Citigroup Conference Dining'
# {'building': '388',
#  'coord': [-74.0113978, 40.7206627],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Citigroup Executive Dining Room'
# {'building': '388',
#  'coord': [-74.0113978, 40.7206627],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# "Dunkin' Donuts, Baskin Robbins"
# {'building': '321',
#  'coord': [-74.0051415, 40.7160577],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Au Bon Pain'
# {'building': '1',
#  'coord': [-74.0132552, 40.7027702],
#  'street': 'State Street Plaza',
#  'zipcode': '10004'}
# 'Table Green Cafe'
# {'building': '',
#  'coord': [-74.0162369, 40.7033145],
#  'street': 'Battery Park',
#  'zipcode': '10004'}
# 'Table Green'
# {'building': '',
#  'coord': [-74.0162369, 40.7033145],
#  'street': 'Battery Park',
#  'zipcode': '10004'}
# "Gregory'S Coffee"
# {'building': '100',
#  'coord': [-74.0069548, 40.7051418],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Starbucks Coffee'
# {'building': '99',
#  'coord': [-74.0072831, 40.7048253],
#  'street': 'Wall Street',
#  'zipcode': '10005'}
# 'Atera'
# {'building': '77',
#  'coord': [-74.0056048, 40.7169484],
#  'street': 'Worth Street',
#  'zipcode': '10013'}
# 'Burger King'
# {'building': '325',
#  'coord': [-74.0050107, 40.7161534],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Arome'
# {'building': '325',
#  'coord': [-74.0050107, 40.7161534],
#  'street': 'Broadway',
#  'zipcode': '10007'}
# 'Subway'
# {'building': '90',
#  'coord': [-74.00492559999999, 40.7161935],
#  'street': 'Worth Street',
#  'zipcode': '10013'}
# 'Starbucks Coffee'
# {'building': '24',
#  'coord': [-74.01405249999999, 40.7025595],
#  'street': 'State Street',
#  'zipcode': '10004'}
# 'Niko Niko Sushi & Bowl'
# {'building': '133',
#  'coord': [-74.0050148, 40.7071791],
#  'street': 'John Street',
#  'zipcode': '10038'}
# "Bubby'S"
# {'building': '120',
#  'coord': [-74.008314, 40.719807],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# 'Mr. Chow Tribecca'
# {'building': '121',
#  'coord': [-74.0089466, 40.7201545],
#  'street': 'Hudson Street',
#  'zipcode': '10013'}
# 'Starbucks'
# {'building': '135',
#  'coord': [-74.0049962, 40.7071539],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Wichcraft'
# {'building': '397',
#  'coord': [-74.0097825, 40.72060090000001],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Plaza Food Court'
# {'building': '1',
#  'coord': [-74.003748, 40.712931],
#  'street': 'Centre Street',
#  'zipcode': '10007'}
# 'Centre Melts'
# {'building': '1',
#  'coord': [-74.003748, 40.712931],
#  'street': 'Centre Street',
#  'zipcode': '10007'}
# 'Nixtamalito'
# {'building': '1',
#  'coord': [-74.003748, 40.712931],
#  'street': 'Centre Street',
#  'zipcode': '10007'}
# 'Koki & Vegi'
# {'building': '1',
#  'coord': [-74.003748, 40.712931],
#  'street': 'Centre Street',
#  'zipcode': '10007'}
# 'Plaza Deli'
# {'building': '127',
#  'coord': [-74.004762, 40.707361],
#  'street': 'John Street',
#  'zipcode': '10038'}
# 'Convene At 32 Old Slip'
# {'building': '32',
#  'coord': [-74.0080471, 40.7037844],
#  'street': 'Old Slip',
#  'zipcode': '10005'}
# 'Hudson River Trading'
# {'building': '32',
#  'coord': [-74.0080471, 40.7037844],
#  'street': 'Old Slip',
#  'zipcode': '10005'}
# 'Corte Cafe'
# {'building': '2',
#  'coord': [-74.00386680000001, 40.7141052],
#  'street': 'Lafayette Street',
#  'zipcode': '10007'}
# 'Albella Ristorante & Bar'
# {'building': '2',
#  'coord': [-74.00386680000001, 40.7141052],
#  'street': 'Lafayette Street',
#  'zipcode': '10007'}
# 'Wall Street Hotel'
# {'building': '129',
#  'coord': [-74.0062351, 40.7051392],
#  'street': 'Front Street',
#  'zipcode': '10005'}
# "Andy'S Cafeteria (Hpd Building)"
# {'building': '100',
#  'coord': [-74.0036216, 40.7102734],
#  'street': 'Gold Street',
#  'zipcode': '10038'}
# 'Flavors Cafe'
# {'building': '175',
#  'coord': [-74.00515639999999, 40.7063764],
#  'street': 'Water Street',
#  'zipcode': '10038'}
# 'Aig 31St Floor Cafe'
# {'building': '175',
#  'coord': [-74.00515639999999, 40.7063764],
#  'street': 'Water Street',
#  'zipcode': '10038'}
# 'A.I.G.Chartis'
# {'building': '175',
#  'coord': [-74.00515639999999, 40.7063764],
#  'street': 'Water Street',
#  'zipcode': '10038'}
# "Claudia'S Coffee Shop"
# {'building': '125',
#  'coord': [-74.0106824, 40.7024877],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Sullivan & Cromwell'
# {'building': '125',
#  'coord': [-74.0106824, 40.7024877],
#  'street': 'Broad Street',
#  'zipcode': '10004'}
# 'Greenwich St Tavern'
# {'building': '399',
#  'coord': [-74.00973630000001, 40.7208529],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Beach Street Eatery'
# {'building': '57',
#  'coord': [-74.0096302, 40.7208395],
#  'street': 'Beach Street',
#  'zipcode': '10013'}
# 'Mon Cher Market'
# {'building': '339',
#  'coord': [-74.004722, 40.716691],
#  'street': 'Broadway',
#  'zipcode': '10013'}
# 'Kaffe 1668'
# {'building': '401',
#  'coord': [-74.009681, 40.720908],
#  'street': 'Greenwich Street',
#  'zipcode': '10013'}
# 'Morgan Stanley Employee Cafeteria'
# {'building': '1',
#  'coord': [-74.01174999999999, 40.70214],
#  'street': 'New York Plaza',
#  'zipcode': '10004'}
# 'Fried Frank Cafeteria'
# {'building': '1',
#  'coord': [-74.01174999999999, 40.70214],
#  'street': 'New York Plaza',
#  'zipcode': '10004'}
# 'Squire Diner'
# {'building': '80',
#  'coord': [-74.0038177, 40.7087043],
#  'street': 'Beekman Street',
#  'zipcode': '10038'}
# 'Seaport Heights Llc'
# {'building': '161',
#  'coord': [-74.0051829, 40.705996],
#  'street': 'Front Street',
#  'zipcode': '10038'}
# 'Maslow 6 Wine Bar'
# {'building': '211',
#  'coord': [-74.00630199999999, 40.718892],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# 'Distilled'
# {'building': '211',
#  'coord': [-74.00630199999999, 40.718892],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# "Zoie'S Cafe And Delicatessen"
# {'building': '49',
#  'coord': [-74.0091255, 40.720799],
#  'street': 'Beach Street',
#  'zipcode': '10013'}
# 'Roast Kitchen'
# {'building': '199',
#  'coord': [-74.00450579999999, 40.7069203],
#  'street': 'Water Street',
#  'zipcode': '10038'}
# 'Gotan'
# {'building': '130',
#  'coord': [-74.0066083, 40.7192553],
#  'street': 'Franklin St',
#  'zipcode': '10013'}
# 'Kori Tribeca'
# {'building': '253',
#  'coord': [-74.0053279, 40.717909],
#  'street': 'Church Street',
#  'zipcode': '10013'}
# 'Terra'
# {'building': '222',
#  'coord': [-74.006548, 40.7192599],
#  'street': 'West Broadway',
#  'zipcode': '10013'}
# "Walker'S Restaurant"
# {'building': '16',
#  'coord': [-74.007032, 40.7196857],
#  'street': 'No Moore Street',
#  'zipcode': '10013'}
# 'Girello'
# {'building': '16',
#  'coord': [-74.007032, 40.7196857],
#  'street': 'North Moore Street',
#  'zipcode': '10013'}
# 'Tutto Il Giorno'
# {'building': '114',
#  'coord': [-74.00597499999999, 40.718806],
#  'street': 'Franklin Street',
#  'zipcode': '10013'}

# %% [markdown]
# ### Delete documents
#
# delete_one(), delete_many()

# %%
#delete one document where name matches condition
db.restaurants.delete_one({"name": "India Garden"})

# %%
#delete all documents where name matches condition
db.restaurants.delete_many({"name": "India Garden"})

# %%
#delete all documents - empties the DB
#db.restaurants.delete_many({})

# %%
#find the first 10 documents in the db - none should be found since the data was deleted 
#cursor = db.restaurants.find().limit(10)
#for document in cursor: 
#    pprint(document)

# %% [markdown]
# ### Explore Further
#
# https://docs.mongodb.com/manual/core/bulk-write-operations/
#
# https://docs.mongodb.com/manual/reference/sql-comparison/
